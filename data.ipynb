# %% [markdown]
# ### Introduction
#
# The application idea revolves around managing and analyzing healthcare workforce data, specifically focusing on Health Professional Shortage Areas (HPSAs) and Medically Underserved Areas (MUAs). The data source is a set of tables representing these areas, obtained from reliable healthcare databases or government health agencies.
#
# The primary goal of the application is to provide insights into the distribution and characteristics of healthcare resources across different regions. It aims to assist healthcare planners, policymakers, and researchers in making informed decisions about resource allocation, identifying areas with shortages, and addressing healthcare disparities.
#
# The core data includes information about various health facilities, their designations, and the status of different HPSAs and MUAs. This data is crucial for understanding the availability of healthcare services in different geographical areas. The application can be a valuable tool for optimizing workforce distribution, improving access to care, and ultimately enhancing overall health outcomes.
#
# The database schema is designed to capture essential information about Health Professional Shortage Areas (HPSAs) and Medically Underserved Areas (MUAs). Here's a brief overview of the schema:
#
# ### Tables:
# hpsa_primary_care:
#
#     Source_ID (Primary Key)
#     Source_Name
#     Status_Code
#     Status_Description
#     Type_Code
#     Type_Desc
#     Address
#     City
#     State_Abbr
#     Postal_Code
#
# hpsa_mental_health:
#
#     Source_ID (Primary Key)
#     Source_Name
#     Status_Code
#     Status_Description
#     Type_Code
#     Type_Desc
#     State_Abbr
#     Degree_of_Shortage
#     Designation_Date
#     Designation_Last_Update_Date
#
# hpsa_dental_health:
#
#     Source_ID (Primary Key)
#     Source_Name
#     Status_Code
#     Status_Description
#     Type_Code
#     Type_Desc
#     Address
#     City
#     State_Abbr
#     Postal_Code
#
# hpsa_mua:
#
#     MUA_SOURCE_ID (Primary Key)
#     MUA_AREA_CD
#     MUA_DESIGNATION_TYP_CD
#     MUA_DESIGNATION_TYP_DESC
#     MUA_STATUS_CD
#     MUA_STATUS_DESC
#     CENSUS_TRACT
#     MUA_DESIGNATION_DT
#     MUA_DESIGNATION_DT_TXT
#     MUA_SCORE
# ### Rationale:
# - Normalization: The schema follows normalization principles to minimize data redundancy and improve data integrity.
#
# - Primary Keys: Each table has a primary key to uniquely identify records.
#
# Consistent Naming: Column names are consistent across tables for similar attributes, facilitating ease of understanding and query writing.
#
# Relationships: While the schema presented here doesn't explicitly show foreign keys, they would be used to establish relationships between tables, ensuring data consistency.
#
# This schema allows for efficient querying and analysis of healthcare workforce data, providing a foundation for the application's functionality.

# %%
import pandas as pd

import mysql.connector
from mysql.connector import Error

# Read the Excel file
filename = 'data.xlsx'
xls = pd.ExcelFile(filename)

# Get the sheet names
sheet_names = xls.sheet_names

# Create a dictionary to store the datasets
datasets = {}

# Loop through each sheet and save the data as a dataset
for sheet_name in sheet_names:
    dataset = pd.read_excel(filename, sheet_name=sheet_name)
    
    # Remove columns with NaN values
    dataset = dataset.dropna(axis=1, how='all')
    
    # Replace NaN values with None
    dataset = dataset.replace(to_replace=float('nan'), value=None)
    
    # Convert columns to appropriate types if needed
    # dataset['column_name'] = pd.to_numeric(dataset['column_name'], errors='coerce')
    
    datasets[sheet_name] = dataset

# Access a specific dataset
sheet1_data = datasets['hpsa_primary_care'] 
sheet2_data = datasets['hpsa_mental_health'] 
sheet3_data = datasets['hpsa_dental_health']
sheet4_data = datasets['hpsa_mua']

# %%
sheet1_data.head()
# Out:
#     Source_ID                                  Source_Name Status_Code  \
# 0  1569995651        Ft. Washakie PHS Indian Health Center           D
# 1  1469994698  McLaughlin PHS Indian Medical/Dental Clinic           D
# 2  1469994687                   Wagner PHS Indian Hospital           D
# 3  141999413V                         Portland Area Office           D
# 4  14099940N2                        Shawnee Health Center           D
#
#   Status_Description Type_Code                                      Type_Desc  \
# 0         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 1         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 2         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 3         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 4         Designated       IHS  Indian, Tribal and Urban Indian Organizations
#
#                    Address           City State_Abbr Postal_Code  ...  \
# 0               PO BOX 128  Fort Washakie         WY  82514-0128  ...
# 1            611 2nd Ave E    Mc Laughlin         SD       57642  ...
# 2    110 Washington Ave NW         Wagner         SD       57380  ...
# 3  1220 SW 3rd Ave Ste 476       Portland         OR  97204-2825  ...
# 4    2307 Gordon Cooper Dr        Shawnee         OK  74801-9007  ...
#
#    Common_Postal_Code       Common_County_Name Common_StateCounty_FIPS  \
# 0               82514       Fremont County, WY                   56013
# 1               57642        Corson County, SD                   46031
# 2               57380   Charles Mix County, SD                   46023
# 3               97204     Multnomah County, OR                   41051
# 4               74801  Pottawatomie County, OK                   40125
#
#   Common_State_Abbr Common_State_Name  Common_State_FIPS Common_Region_Name  \
# 0                WY           Wyoming                 56        Region VIII
# 1                SD      South Dakota                 46        Region VIII
# 2                SD      South Dakota                 46        Region VIII
# 3                OR            Oregon                 41           Region X
# 4                OK          Oklahoma                 40          Region VI
#
#    Rural_Status_Code Rural_Status_Desc  \
# 0                  R             Rural
# 1                  R             Rural
# 2                  R             Rural
# 3                  N         Non-Rural
# 4                  R             Rural
#
#                   HPSA_Designation_Pop_Type_Desc
# 0  Indian, Tribal and Urban Indian Organizations
# 1  Indian, Tribal and Urban Indian Organizations
# 2  Indian, Tribal and Urban Indian Organizations
# 3  Indian, Tribal and Urban Indian Organizations
# 4  Indian, Tribal and Urban Indian Organizations
#
# [5 rows x 55 columns]

# %%
sheet2_data.head()
# Out:
#     Source_ID                           Source_Name Status_Code  \
# 0      733007                                  Coos           W
# 1  7449994412  Northern Rhode Island Catchment Area           W
# 2  7449994412  Northern Rhode Island Catchment Area           W
# 3  7449994412  Northern Rhode Island Catchment Area           W
# 4  7449994412  Northern Rhode Island Catchment Area           W
#
#   Status_Description Type_Code        Type_Desc State_Abbr Degree_of_Shortage  \
# 0          Withdrawn  Hpsa Geo  Geographic HPSA         NH     Not applicable
# 1          Withdrawn  Hpsa Geo  Geographic HPSA         RI     Not applicable
# 2          Withdrawn  Hpsa Geo  Geographic HPSA         RI     Not applicable
# 3          Withdrawn  Hpsa Geo  Geographic HPSA         RI     Not applicable
# 4          Withdrawn  Hpsa Geo  Geographic HPSA         RI     Not applicable
#
#    Designation_Date  Designation_Last_Update_Date  ... Common_State_Abbr  \
# 0             29005                         37799  ...                NH
# 1             37672                         39671  ...                RI
# 2             37672                         39671  ...                RI
# 3             37672                         39671  ...                RI
# 4             37672                         39671  ...                RI
#
#   Common_State_Name Common_State_FIPS Common_Region_Name HPSA_Withdrawn_Date  \
# 0     New Hampshire                33           Region I               37799
# 1      Rhode Island                44           Region I               39671
# 2      Rhode Island                44           Region I               39671
# 3      Rhode Island                44           Region I               39671
# 4      Rhode Island                44           Region I               39671
#
#   HPSA_Withdrawn_Date_String Provider_Type Rural_Status_Code  \
# 0                  6/27/2003          None                 R
# 1                  8/11/2008          None              None
# 2                  8/11/2008          None              None
# 3                  8/11/2008          None              None
# 4                  8/11/2008          None              None
#
#   Rural_Status_Desc  HPSA_Designation_Pop_Type_Desc
# 0             Rural           Geographic Population
# 1              None           Geographic Population
# 2              None           Geographic Population
# 3              None           Geographic Population
# 4              None           Geographic Population
#
# [5 rows x 64 columns]

# %%
sheet3_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'Address', 'City', 'State_Abbr',
#        'Postal_Code', 'Designation_Date', 'Designation_Last_Update_Date',
#        'Designation_Pop', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc', 'Component_Source_ID',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Geography_ID', 'CountyFIPS', 'County_Name', 'StateCountyFIPS',
#        'State_FIPS', 'State_Abbr_2', 'State_Name', 'Primary_State_Name',
#        'Primary_State_FIPS', 'Primary_HHS_Region_Name',
#        'US_Mexico_Border_County', 'US_Mexico_Border_100km',
#        'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'Geocoding_Primary_X',
#        'Geocoding_Primary_Y', 'Common_City_Name_with_State_Abbr',
#        'Common_Postal_Code', 'Common_County_Name', 'Common_StateCounty_FIPS',
#        'Common_State_Abbr', 'Common_State_Name', 'Common_State_FIPS',
#        'Common_Region_Name', 'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet3_data.head()
# Out:
#     Source_ID                              Source_Name Status_Code  \
# 0  6409994016              Carl Albert Indian Hospital           W
# 1  6319993124            Winnebago PHS Indian Hospital           W
# 2  6089990849  Southern Colorado Ute Services Unit-Fed           W
# 3  60499904B5   Phx Area Office Two Renaissance Square           W
# 4  6569995629    Ft. Washakie PHS Indian Health Center           D
#
#   Status_Description Type_Code                                      Type_Desc  \
# 0          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 1          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 2          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 3          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 4         Designated       IHS  Indian, Tribal and Urban Indian Organizations
#
#                   Address           City State_Abbr Postal_Code  ...  \
# 0  1001 N Country Club Rd            Ada         OK  74820-2847  ...
# 1               PO BOX Hh      Winnebago         NE  68071-0767  ...
# 2           Weeminuche Dr        Ignacio         CO       81137  ...
# 3            100 N 1st St        Phoenix         AZ       85004  ...
# 4              PO BOX 128  Fort Washakie         WY  82514-0128  ...
#
#    Common_Postal_Code   Common_County_Name Common_StateCounty_FIPS  \
# 0               74820  Pontotoc County, OK                   40123
# 1               68071  Thurston County, NE                   31173
# 2               81137  La Plata County, CO                    8067
# 3               85004  Maricopa County, AZ                    4013
# 4               82514   Fremont County, WY                   56013
#
#   Common_State_Abbr Common_State_Name  Common_State_FIPS Common_Region_Name  \
# 0                OK          Oklahoma                 40          Region VI
# 1                NE          Nebraska                 31         Region VII
# 2                CO          Colorado                  8        Region VIII
# 3                AZ           Arizona                  4          Region IX
# 4                WY           Wyoming                 56        Region VIII
#
#    Rural_Status_Code Rural_Status_Desc  \
# 0                  R             Rural
# 1                  R             Rural
# 2                  R             Rural
# 3                  N         Non-Rural
# 4                  R             Rural
#
#                   HPSA_Designation_Pop_Type_Desc
# 0  Indian, Tribal and Urban Indian Organizations
# 1  Indian, Tribal and Urban Indian Organizations
# 2  Indian, Tribal and Urban Indian Organizations
# 3  Indian, Tribal and Urban Indian Organizations
# 4  Indian, Tribal and Urban Indian Organizations
#
# [5 rows x 55 columns]

# %%
sheet4_data.columns
# Out:
# Index(['MUA_SOURCE_ID', 'MUA_AREA_CD', 'MUA_DESIGNATION_TYP_CD',
#        'MUA_DESIGNATION_TYP_DESC', 'MUA_STATUS_CD', 'MUA_STATUS_DESC',
#        'CENSUS_TRACT', 'MUA_DESIGNATION_DT', 'MUA_DESIGNATION_DT_TXT',
#        'MUA_SCORE', 'MUA_SERVICE_AREA_NM', 'MUA_UPDATE_DT',
#        'MUA_UPDATE_DT_TXT', 'US_MEXICO_BORDER_100KM_IND',
#        'US_MEXICO_BORDER_COUNTY_IND', 'STATE_COUNTY_FIPS_CD', 'COUNTY_FIPS_CD',
#        'LIST_BOX_COUNTY_NM', 'COUNTY_NM', 'COUNTY_DESC', 'REGION_CD',
#        'REGION_NM', 'STATE_FIPS_CD', 'STATE_NM', 'STATE_ABBR',
#        'POVERTY_100_PCT_NUM', 'POP_AGE_65_OVER_PCT', 'INFANT_MORTALITY_RATE',
#        'DW_RECORD_CREATE_DT', 'DW_RECORD_CREATE_DT_TXT',
#        'PRIMARY_STATE_FIPS_CD', 'PRIMARY_STATE_ABBR', 'PRIMARY_STATE_NM',
#        'PRIMARY_REGION_CD', 'PRIMARY_REGION_NM', 'CMN_REGION_CD',
#        'CMN_REGION_NM', 'CMN_STATE_NM', 'CMN_STATE_ABBR', 'CMN_STATE_FIPS_CD',
#        'CMN_STATE_COUNTY_FIPS_CD', 'CMN_COUNTY_NM_STATE_ABBR',
#        'BREAK_DESIGNATION_IND', 'MUA_COMP_DESIGNATION_DT',
#        'MUA_COMP_DESIGNATION_DT_TXT', 'MUA_COMP_GEO_NM', 'MUA_COMP_GEO_TYP_CD',
#        'MUA_COMP_GEO_TYP_DESC', 'MUA_COMP_GEO_TYP_ID',
#        'MUA_COMP_LAST_UPDATE_DT', 'MUA_COMP_STATUS_CD', 'MUA_COMP_STATUS_DESC',
#        'MUA_COMP_UPDATE_DT_TXT', 'MUA_DESIGNATION_POP', 'MUA_METRO_IND_CD',
#        'MUA_METRO_IND_DESC', 'MUA_METRO_IND_ID', 'MUA_POPULATION_TYP_CD',
#        'MUA_POPULATION_TYP_DESC', 'MUA_POPULATION_TYP_ID', 'MUA_RES_CIV_POP',
#        'RURAL_STATUS_CD', 'RURAL_STATUS_DESC', 'PROVIDER_1000_POP'],
#       dtype='object')

# %%
sheet4_data.head()
# Out:
#    MUA_SOURCE_ID  MUA_AREA_CD MUA_DESIGNATION_TYP_CD  \
# 0            474   9013530200                    MUP
# 1            474   9013530100                    MUP
# 2            470   9005310300                    MUP
# 3            470   9005310500                    MUP
# 4            470   9005310801                    MUP
#
#            MUA_DESIGNATION_TYP_DESC MUA_STATUS_CD MUA_STATUS_DESC  \
# 0  Medically Underserved Population             D      Designated
# 1  Medically Underserved Population             D      Designated
# 2  Medically Underserved Population             D      Designated
# 3  Medically Underserved Population             D      Designated
# 4  Medically Underserved Population             D      Designated
#
#    CENSUS_TRACT  MUA_DESIGNATION_DT MUA_DESIGNATION_DT_TXT  MUA_SCORE  ...  \
# 0       5302.00               34676              12/8/1994       47.8  ...
# 1       5301.00               34676              12/8/1994       47.8  ...
# 2       3103.00               34676              12/8/1994       41.1  ...
# 3       3105.00               34676              12/8/1994       41.1  ...
# 4       3108.01               34676              12/8/1994       41.1  ...
#
#   MUA_METRO_IND_CD  MUA_METRO_IND_DESC MUA_METRO_IND_ID MUA_POPULATION_TYP_CD  \
# 0                0             Unknown                0                    LI
# 1                0             Unknown                0                    LI
# 2                0             Unknown                0                    LI
# 3                0             Unknown                0                    LI
# 4                0             Unknown                0                    LI
#
#   MUA_POPULATION_TYP_DESC  MUA_POPULATION_TYP_ID  MUA_RES_CIV_POP  \
# 0          MUP Low Income                      2             None
# 1          MUP Low Income                      2             None
# 2          MUP Low Income                      2             None
# 3          MUP Low Income                      2             None
# 4          MUP Low Income                      2             None
#
#   RURAL_STATUS_CD RURAL_STATUS_DESC PROVIDER_1000_POP
# 0               N         Non-Rural              None
# 1               N         Non-Rural              None
# 2               R             Rural              None
# 3               R             Rural              None
# 4               R             Rural              None
#
# [5 rows x 64 columns]

# %% [markdown]
# ### Stored Procedures:
# 1. usp_GetAverageScoreByMUAStatus
# Purpose: This stored procedure calculates and returns the average MUA score for each MUA status.
#
# - How it works:
# ```
# CREATE PROCEDURE usp_GetAverageScoreByMUAStatus
#     AS
#     BEGIN
#         SELECT
#             MUA_STATUS_DESC,
#             AVG(CAST(MUA_SCORE AS FLOAT)) AS Average_Score
#         FROM
#             hpsa_mua
#         GROUP BY
#             MUA_STATUS_DESC;
#     END;
# ```
# - Usage in Application:
# This procedure provides a quick overview of the average MUA scores based on different MUA statuses. It aids in identifying trends and disparities in healthcare accessibility across various designations.
#
# 2. usp_GetHPSAByStateAndType
# Purpose: This stored procedure retrieves HPSAs based on the provided state abbreviation and type code.
#
# How it works:
# ```
# CREATE PROCEDURE usp_GetHPSAByStateAndType
#     @StateAbbreviation NVARCHAR(2),
#     @TypeCode NVARCHAR(10)
# AS
# BEGIN
#     SELECT *
#     FROM
#         hpsa_primary_care
#     WHERE
#         State_Abbr = @StateAbbreviation
#         AND Type_Code = @TypeCode;
# END;
# ```
# - Usage in Application:
# It allows the application to fetch specific HPSAs based on user-inputted criteria, helping healthcare planners to focus on areas of interest and address shortages effectively.
#
# ![image1](image1.png)
#
#
# ### Queries
# 1. Average Score of Designated MUAs:
# Purpose: To retrieve the average MUA score for designated areas.
# ```
# SELECT
#     MUA_STATUS_DESC,
#     AVG(CAST(MUA_SCORE AS FLOAT)) AS Average_Score
# FROM
#     hpsa_mua
# WHERE
#     MUA_STATUS_DESC = 'Designated'
# GROUP BY
#     MUA_STATUS_DESC;
# ```
# 2. HPSAs in a Specific State and Type:
# Purpose: To fetch HPSAs in a particular state and of a specific type.
# ```
# SELECT *
# FROM
#     hpsa_primary_care
# WHERE
#     State_Abbr = 'CA'
#     AND Type_Code = 'IHS';
# ```
#
# 3. Designated Mental Health HPSAs:
# Purpose: To retrieve information about designated mental health HPSAs.
#
# ```
# SELECT *
# FROM
#     hpsa_mental_health
# WHERE
#     Status_Description = 'Designated';
# ```
#
# 4. MUAs with the Highest Scores:
# Purpose: To find MUAs with the highest scores.
#
# ```
# SELECT TOP 5
#     *
# FROM
#     hpsa_mua
# ORDER BY
#     MUA_SCORE DESC;
# ```
#
# How they are used in Application:
#
# - The average MUA score query aids in displaying a summary of MUA scores.
# - The HPSA retrieval query allows users to explore specific HPSAs based on state and type.
# - The designated mental health HPSAs query provides insights into areas specifically designated for mental health.
# - The query for MUAs with the highest scores helps identify areas with the greatest need for attention and resources.
# - These queries and procedures collectively empower the application to offer detailed insights into healthcare workforce distribution and shortages, supporting informed decision-making.
#
# ![image4](image4.png)

# %% [markdown]
# - Database Connection:
#
# Attempts to connect to a MySQL database using the provided host, user, password, and database information.
# - Table Creation and Data Insertion:
#
# Defines four datasets, each representing a table (hpsa_primary_care, hpsa_mental_health, hpsa_dental_health, and hpsa_mua).
# For each dataset, it dynamically generates a CREATE TABLE query based on the column names and their types (assumed VARCHAR(255)).
# Executes the CREATE TABLE query to create a table in the MySQL database.
# Prepares and executes an INSERT query to insert the data from the dataset into the corresponding table.
# - Commit Changes:
#
# Commits the changes to the database. This step is crucial for the changes to take effect permanently.
# - Error Handling:
#
# If any error occurs during the process (such as a connection error, SQL syntax error, etc.), it prints an error message.
# - Connection Closure:
#
# Closes the cursor and the database connection, ensuring proper cleanup.
# This script is designed to initialize a MySQL database by creating tables based on provided datasets and inserting data into these tables. It's a common approach when setting up a database for the first time or when updating the schema with new data.
#
# ![image5](image5.png)

# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error

# Database connection details
host = 'localhost'
user = 'fr34k'
password = '1391'
database = 'task_x'

# Create a MySQL connection
try:
    conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
    if conn.is_connected():
        print('Connected to MySQL database')

        # Create a cursor
        cursor = conn.cursor()

        # Drop tables if they exist
        cursor.execute("DROP TABLE IF EXISTS hpsa_primary_care")
        cursor.execute("DROP TABLE IF EXISTS hpsa_mental_health")
        cursor.execute("DROP TABLE IF EXISTS hpsa_dental_health")
        cursor.execute("DROP TABLE IF EXISTS hpsa_mua")

        # Insert datasets into MySQL tables
        datasets = [(sheet1_data.iloc[:, :10], 'hpsa_primary_care'), 
                    (sheet2_data.iloc[:, :10], 'hpsa_mental_health'),
                    (sheet3_data.iloc[:, :10], 'hpsa_dental_health'), 
                    (sheet4_data.iloc[:, :10], 'hpsa_mua')]

        for dataset, table_name in datasets:
            column_names = list(dataset.columns)
            values = dataset.values.tolist()

            # Generate column definitions with types
            column_definitions = ', '.join([f'{column} VARCHAR(255)' for column in column_names])

            # Create table with column names and types
            create_table_query = f"CREATE TABLE {table_name} ({column_definitions})"
            cursor.execute(create_table_query)

            placeholders = ', '.join(['%s'] * len(column_names))

            # Insert data into table
            insert_query = f"INSERT INTO {table_name} ({', '.join(column_names)}) VALUES ({placeholders})"
            cursor.executemany(insert_query, values)

        # Commit the changes
        conn.commit()
        print('Data inserted into MySQL tables')

except Error as e:
    print(f"Error: {e}")

finally:
    # Close the cursor and connection
    if conn.is_connected():
        cursor.close()
        conn.close()
        print('You can now select from tables')
# Out:
# Connected to MySQL database
# Data inserted into MySQL tables
# You can now select from tables

# %% [markdown]
# This Python code establishes a connection to a MySQL database using the mysql.connector library. It prompts the user to input a SQL query, then executes the query and fetches all rows from the result. Finally, it prints each row to the console.
#
# Here's a breakdown:
#
# - Database Connection:
#
# It attempts to connect to a MySQL database using the provided host, user, password, and database information.
#
# - User Input:
#
# The user is prompted to enter a SQL query they want to perform on the connected database.
#
# - Query Execution:
#
# The provided SQL query is executed using the database cursor.
# - Fetching and Printing Rows:
#
# All rows resulting from the query execution are fetched.
# Each row is printed to the console.
# - Error Handling:
#
# If any error occurs during the process, it prints an error message.
# - Connection Closure:
#
# Finally, it closes the cursor and the database connection.
# This code allows users to interactively input and execute SQL queries on the connected MySQL database, providing a flexible way to explore and retrieve data.
# ![image2](image2.png)

# %%
# Create a MySQL connection
try:
    conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
    if conn.is_connected():
        print('Connected to MySQL database')

        # Create a cursor
        cursor = conn.cursor()

        # Select all rows from a table
        select_query = input(str("Enter a query to perform: ")) #"SELECT * FROM hpsa_mua where hpsa_mua.mua_source_ID > 1000;"
        cursor.execute(select_query)

        # Fetch all rows
        rows = cursor.fetchall()

        # Print the rows
        for row in rows:
            print(row)

except Error as e:
    print(f"Error: {e}")

finally:
    # Close the cursor and connection
    if conn.is_connected():
        cursor.close()
        conn.close()
        print('Connection closed')
# Out:
# Connected to MySQL database
# Enter a query to perform: select * from hpsa_mua
# ('474', '9013530200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '5302.0', '34676', '12/8/1994', '47.8')
# ('474', '9013530100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '5301.0', '34676', '12/8/1994', '47.8')
# ('470', '9005310300', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '3103.0', '34676', '12/8/1994', '41.1')
# ('470', '9005310500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '3105.0', '34676', '12/8/1994', '41.1')
# ('470', '9005310801', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '3108.01', '34676', '12/8/1994', '41.1')
# ('470', '9005310100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '3101.0', '34676', '12/8/1994', '41.1')
# ('470', '9005310200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '3102.0', '34676', '12/8/1994', '41.1')
# ('468', '9003417100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4171.0', '34676', '12/8/1994', '41.6')
# ('468', '9003417200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4172.0', '34676', '12/8/1994', '41.6')
# ('468', '9003415900', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4159.0', '34676', '12/8/1994', '41.6')
# ('468', '9003416000', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4160.0', '34676', '12/8/1994', '41.6')
# ('468', '9003416100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4161.0', '34676', '12/8/1994', '41.6')
# ('468', '9003416200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4162.0', '34676', '12/8/1994', '41.6')
# ('468', '9003416600', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4166.0', '34676', '12/8/1994', '41.6')
# ('468', '9003416800', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4168.0', '34676', '12/8/1994', '41.6')
# ('468', '9003417400', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4174.0', '34676', '12/8/1994', '41.6')
# ('468', '9003417500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '4175.0', '34676', '12/8/1994', '41.6')
# ('467', '9001080100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '801.0', '34676', '12/8/1994', '62.5')
# ('467', '9001080200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '802.0', '34676', '12/8/1994', '62.5')
# ('467', '9001080400', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '804.0', '34676', '12/8/1994', '62.5')
# ('466', '9001990000', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '9900.0', '34676', '12/8/1994', '46.8')
# ('466', '9001044100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '441.0', '34676', '12/8/1994', '46.8')
# ('466', '9001044200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '442.0', '34676', '12/8/1994', '46.8')
# ('466', '9001044400', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '444.0', '34676', '12/8/1994', '46.8')
# ('466', '9001044500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '445.0', '34676', '12/8/1994', '46.8')
# ('466', '9001044000', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '440.0', '34676', '12/8/1994', '46.8')
# ('465', '9001210800', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2108.0', '34764', '3/6/1995', '52.9')
# ('465', '9001211000', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2110.0', '34764', '3/6/1995', '52.9')
# ('465', '9001211200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2112.0', '34764', '3/6/1995', '52.9')
# ('465', '9001211300', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2113.0', '34764', '3/6/1995', '52.9')
# ('465', '9001211400', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2114.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210600', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2106.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210702', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2107.02', '34764', '3/6/1995', '52.9')
# ('465', '9001210100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2101.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210900', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2109.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2102.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210400', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2104.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2105.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210701', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2107.01', '34764', '3/6/1995', '52.9')
# ('465', '9001211100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2111.0', '34764', '3/6/1995', '52.9')
# ('465', '9001210300', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '2103.0', '34764', '3/6/1995', '52.9')
# ('4013', '9003406100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4061.0', '35460', '1/30/1997', '56.8')
# ('4013', '9003405700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4057.0', '35460', '1/30/1997', '56.8')
# ('492', '9009351200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3512.0', '34465', '5/11/1994', '59.8')
# ('491', '9009350800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3508.0', '34465', '5/11/1994', '59.8')
# ('490', '9009350100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3501.0', '34465', '5/11/1994', '59.8')
# ('477', '9009170100', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '1701.0', '33840', '8/24/1992', '0.0')
# ('477', '9009170200', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '1702.0', '33840', '8/24/1992', '0.0')
# ('472', '9009351400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3514.0', '34625', '10/18/1994', '59.8')
# ('472', '9009350400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3504.0', '34625', '10/18/1994', '59.8')
# ('472', '9009350500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3505.0', '34625', '10/18/1994', '59.8')
# ('472', '9009350200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3502.0', '34625', '10/18/1994', '59.8')
# ('472', '9009350300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3503.0', '34625', '10/18/1994', '59.8')
# ('476', '9001022200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '222.0', '34067', '4/8/1993', '58.3')
# ('476', '9001022300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '223.0', '34067', '4/8/1993', '58.3')
# ('478', '9015800400', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '8004.0', '33725', '5/1/1992', '0.0')
# ('478', '9015800500', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '8005.0', '33725', '5/1/1992', '0.0')
# ('478', '9015800700', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '8007.0', '33725', '5/1/1992', '0.0')
# ('478', '9015800600', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '8006.0', '33725', '5/1/1992', '0.0')
# ('478', '9015800300', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '8003.0', '33725', '5/1/1992', '0.0')
# ('483', '9009142604', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1426.04', '30209', '9/15/1982', '52.2')
# ('483', '9009142100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1421.0', '30209', '9/15/1982', '52.2')
# ('483', '9009142200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1422.0', '30209', '9/15/1982', '52.2')
# ('483', '9009142300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1423.0', '30209', '9/15/1982', '52.2')
# ('483', '9009142400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1424.0', '30209', '9/15/1982', '52.2')
# ('483', '9009142500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1425.0', '30209', '9/15/1982', '52.2')
# ('483', '9009142601', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1426.01', '30209', '9/15/1982', '52.2')
# ('483', '9009142603', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1426.03', '30209', '9/15/1982', '52.2')
# ('482', '9009140300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1403.0', '30209', '9/15/1982', '59.6')
# ('482', '9009140400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1404.0', '30209', '9/15/1982', '59.6')
# ('482', '9009140500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1405.0', '30209', '9/15/1982', '59.6')
# ('482', '9009140600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1406.0', '30209', '9/15/1982', '59.6')
# ('482', '9009140700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1407.0', '30209', '9/15/1982', '59.6')
# ('482', '9009141500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1415.0', '30209', '9/15/1982', '59.6')
# ('482', '9009141600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1416.0', '30209', '9/15/1982', '59.6')
# ('482', '9009140200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1402.0', '30209', '9/15/1982', '59.6')
# ('481', '9003524700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5247.0', '30033', '3/23/1982', '39.1')
# ('481', '9003504500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5045.0', '30033', '3/23/1982', '39.1')
# ('481', '9003504900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5049.0', '30033', '3/23/1982', '39.1')
# ('480', '9003524400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5244.0', '30033', '3/23/1982', '46.8')
# ('480', '9003502800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5028.0', '30033', '3/23/1982', '46.8')
# ('480', '9003502900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5029.0', '30033', '3/23/1982', '46.8')
# ('480', '9003503000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5030.0', '30033', '3/23/1982', '46.8')
# ('480', '9003500900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5009.0', '30033', '3/23/1982', '46.8')
# ('480', '9003501200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5012.0', '30033', '3/23/1982', '46.8')
# ('480', '9003501500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5015.0', '30033', '3/23/1982', '46.8')
# ('480', '9003501700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5017.0', '30033', '3/23/1982', '46.8')
# ('480', '9003501800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5018.0', '30033', '3/23/1982', '46.8')
# ('480', '9003501400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5014.0', '30033', '3/23/1982', '46.8')
# ('480', '9003501300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5013.0', '30033', '3/23/1982', '46.8')
# ('480', '9003503500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5035.0', '30033', '3/23/1982', '46.8')
# ('480', '9003503700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5037.0', '30033', '3/23/1982', '46.8')
# ('485', '9001074000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '740.0', '34458', '5/4/1994', '54.6')
# ('485', '9001070600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '706.0', '34458', '5/4/1994', '54.6')
# ('485', '9001071300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '713.0', '34458', '5/4/1994', '54.6')
# ('485', '9001257200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2572.0', '34458', '5/4/1994', '54.6')
# ('485', '9001073900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '739.0', '34458', '5/4/1994', '54.6')
# ('485', '9001071400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '714.0', '34458', '5/4/1994', '54.6')
# ('485', '9001071600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '716.0', '34458', '5/4/1994', '54.6')
# ('485', '9001073500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '735.0', '34458', '5/4/1994', '54.6')
# ('485', '9001073600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '736.0', '34458', '5/4/1994', '54.6')
# ('485', '9001073800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '738.0', '34458', '5/4/1994', '54.6')
# ('484', '9001070900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '709.0', '34458', '5/4/1994', '59.6')
# ('484', '9001071000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '710.0', '34458', '5/4/1994', '59.6')
# ('484', '9001070200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '702.0', '34458', '5/4/1994', '59.6')
# ('484', '9001070500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '705.0', '34458', '5/4/1994', '59.6')
# ('484', '9001070300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '703.0', '34458', '5/4/1994', '59.6')
# ('484', '9001070400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '704.0', '34458', '5/4/1994', '59.6')
# ('484', '9001070600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '706.0', '34458', '5/4/1994', '59.6')
# ('479', '9007541600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5416.0', '33329', '4/1/1991', '52.5')
# ('489', '9003502100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5021.0', '34465', '5/11/1994', '60.9')
# ('488', '9003500500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5005.0', '34465', '5/11/1994', '60.2')
# ('487', '9011870200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8702.0', '34465', '5/11/1994', '54.4')
# ('487', '9011702300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7023.0', '34465', '5/11/1994', '54.4')
# ('486', '9011690500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6905.0', '34465', '5/11/1994', '47.7')
# ('486', '9011696800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6968.0', '34465', '5/11/1994', '47.7')
# ('486', '9011870300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8703.0', '34465', '5/11/1994', '47.7')
# ('1442', '23005000300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3.0', '29914', '11/24/1981', '54.05')
# ('1442', '23005000600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6.0', '29914', '11/24/1981', '54.05')
# ('1465', '23001010100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '101.0', '34465', '5/11/1994', '60.9')
# ('1459', '23001020300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '203.0', '34465', '5/11/1994', '55.85')
# ('1459', '23001020100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '201.0', '34465', '5/11/1994', '55.85')
# ('7965', '25013812702', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '8127.02', '41822', '7/2/2014', '61.5')
# ('7965', '25013812500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '8125.0', '41822', '7/2/2014', '61.5')
# ('7965', '25013812701', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '8127.01', '41822', '7/2/2014', '61.5')
# ('6154', '25001011802', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '118.02', '36781', '9/12/2000', '57.3')
# ('6154', '25001012001', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '120.01', '36781', '9/12/2000', '57.3')
# ('6154', '25001012700', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '127.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001012800', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '128.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001010800', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '108.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001010900', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '109.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001011002', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '110.02', '36781', '9/12/2000', '57.3')
# ('6154', '25001011500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '115.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001011600', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '116.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001011700', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '117.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001011801', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '118.01', '36781', '9/12/2000', '57.3')
# ('6154', '25001011100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '111.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001011200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '112.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001011300', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '113.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001011400', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '114.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001012502', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '125.02', '36781', '9/12/2000', '57.3')
# ('6154', '25001012601', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '126.01', '36781', '9/12/2000', '57.3')
# ('6154', '25001012900', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '129.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001015300', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '153.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001990000', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '9900.0', '36781', '9/12/2000', '57.3')
# ('6154', '25001012602', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '126.02', '36781', '9/12/2000', '57.3')
# ('6154', '25001012102', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '121.02', '36781', '9/12/2000', '57.3')
# ('6154', '25001012101', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '121.01', '36781', '9/12/2000', '57.3')
# ('6154', '25001012002', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '120.02', '36781', '9/12/2000', '57.3')
# ('7470', '25009221400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2214.0', '38443', '4/1/2005', '59.5')
# ('7470', '25009221500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2215.0', '38443', '4/1/2005', '59.5')
# ('7470', '25009221600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2216.0', '38443', '4/1/2005', '59.5')
# ('7470', '25009221700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2217.0', '38443', '4/1/2005', '59.5')
# ('7320', '25013812300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8123.0', '37708', '3/28/2003', '61.7')
# ('7320', '25013812403', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8124.03', '37708', '3/28/2003', '61.7')
# ('7320', '25013812404', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8124.04', '37708', '3/28/2003', '61.7')
# ('5021', '25013802200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8022.0', '36245', '3/26/1999', '56.8')
# ('5021', '25013802300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8023.0', '36245', '3/26/1999', '56.8')
# ('5020', '25013800101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8001.01', '36245', '3/26/1999', '57.7')
# ('5020', '25013800102', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8001.02', '36245', '3/26/1999', '57.7')
# ('5020', '25013800202', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8002.02', '36245', '3/26/1999', '57.7')
# ('1543', '25027732001', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7320.01', '34481', '5/27/1994', '57.1')
# ('1536', '25027709600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7096.0', '34481', '5/27/1994', '56.5')
# ('1536', '25027710700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7107.0', '34481', '5/27/1994', '56.5')
# ('1536', '25027710800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7108.0', '34481', '5/27/1994', '56.5')
# ('1532', '25005651300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6513.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005651700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6517.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005651800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6518.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005651900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6519.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005652600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6526.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005652700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6527.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005650800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6508.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005650900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6509.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005651100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6511.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005651200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6512.0', '30810', '5/8/1984', '61.4')
# ('1532', '25005650700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6507.0', '30810', '5/8/1984', '61.4')
# ('1512', '25023510300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5103.0', '33843', '8/27/1992', '43.6')
# ('1512', '25023510400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5104.0', '33843', '8/27/1992', '43.6')
# ('1512', '25023510800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5108.0', '33843', '8/27/1992', '43.6')
# ('1512', '25023510900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5109.0', '33843', '8/27/1992', '43.6')
# ('1512', '25023511000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5110.0', '33843', '8/27/1992', '43.6')
# ('1512', '25023511400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5114.0', '33843', '8/27/1992', '43.6')
# ('1512', '25023511500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5115.0', '33843', '8/27/1992', '43.6')
# ('7013', '25005640800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6408.0', '30820', '5/18/1984', '55.2')
# ('7013', '25005642000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6420.0', '30820', '5/18/1984', '55.2')
# ('7013', '25005641300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6413.0', '30820', '5/18/1984', '55.2')
# ('7013', '25005640901', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6409.01', '30820', '5/18/1984', '55.2')
# ('7013', '25005641000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6410.0', '30820', '5/18/1984', '55.2')
# ('7013', '25005641101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6411.01', '30820', '5/18/1984', '55.2')
# ('7013', '25005641400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6414.0', '30820', '5/18/1984', '55.2')
# ('1530', '25027732500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7325.0', '30809', '5/7/1984', '59.1')
# ('1530', '25027733000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7330.0', '30809', '5/7/1984', '59.1')
# ('1530', '25027731203', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7312.03', '30809', '5/7/1984', '59.1')
# ('1530', '25027731204', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7312.04', '30809', '5/7/1984', '59.1')
# ('1530', '25027731300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7313.0', '30809', '5/7/1984', '59.1')
# ('1530', '25027731400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7314.0', '30809', '5/7/1984', '59.1')
# ('1530', '25027731500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7315.0', '30809', '5/7/1984', '59.1')
# ('1530', '25027731700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7317.0', '30809', '5/7/1984', '59.1')
# ('1530', '25027731202', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7312.02', '30809', '5/7/1984', '59.1')
# ('1523', '25021417801', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4178.01', '29990', '2/8/1982', '57.0')
# ('1523', '25021417802', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4178.02', '29990', '2/8/1982', '57.0')
# ('1522', '25017311300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3113.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017388300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3883.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017310100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3101.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017310400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3104.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017310700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3107.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017311100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3111.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017311200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3112.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017311700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3117.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017311800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3118.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017311900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3119.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017312000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3120.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017312200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3122.0', '30379', '3/4/1983', '61.9')
# ('1522', '25017312400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3124.0', '30379', '3/4/1983', '61.9')
# ('1519', '25013811400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8114.0', '34459', '5/5/1994', '55.93')
# ('1519', '25013811600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8116.0', '34459', '5/5/1994', '55.93')
# ('1519', '25013811700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8117.0', '34459', '5/5/1994', '55.93')
# ('1518', '25009990100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9901.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009205100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2051.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009205200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2052.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2060.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2061.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2062.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2064.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2065.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2066.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2067.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2068.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009207000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2070.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009207100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2071.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009207200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2072.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2063.0', '31453', '2/10/1986', '55.7')
# ('1518', '25009206900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2069.0', '31453', '2/10/1986', '55.7')
# ('1517', '25009251200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2512.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2504.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2501.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2502.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2503.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009251100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2511.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2507.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2508.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2509.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009251000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2510.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009251300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2513.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009251400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2514.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2505.0', '30868', '7/5/1984', '53.9')
# ('1517', '25009250600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2506.0', '30868', '7/5/1984', '53.9')
# ('1534', '25025170702', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1707.02', '34459', '5/5/1994', '61.9')
# ('1534', '25025170800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1708.0', '34459', '5/5/1994', '61.9')
# ('1534', '25025990101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9901.01', '34459', '5/5/1994', '61.9')
# ('1534', '25025170100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1701.0', '34459', '5/5/1994', '61.9')
# ('1534', '25025170200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1702.0', '34459', '5/5/1994', '61.9')
# ('1534', '25025170300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1703.0', '34459', '5/5/1994', '61.9')
# ('1534', '25025170400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1704.0', '34459', '5/5/1994', '61.9')
# ('1534', '25025170501', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1705.01', '34459', '5/5/1994', '61.9')
# ('1534', '25025170502', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1705.02', '34459', '5/5/1994', '61.9')
# ('1534', '25025170601', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1706.01', '34459', '5/5/1994', '61.9')
# ('1534', '25025170701', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1707.01', '34459', '5/5/1994', '61.9')
# ('1533', '25025050901', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '509.01', '34459', '5/5/1994', '58.2')
# ('1533', '25025051000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '510.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025051101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '511.01', '34459', '5/5/1994', '58.2')
# ('1533', '25025051200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '512.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025981300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9813.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025050400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '504.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025981600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9816.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025050101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '501.01', '34459', '5/5/1994', '58.2')
# ('1533', '25025050200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '502.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025050300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '503.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025050500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '505.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025050600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '506.0', '34459', '5/5/1994', '58.2')
# ('1533', '25025050700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '507.0', '34459', '5/5/1994', '58.2')
# ('1529', '25025981201', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9812.01', '30062', '4/21/1982', '36.2')
# ('1529', '25025061101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '611.01', '30062', '4/21/1982', '36.2')
# ('1528', '25025120105', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1201.05', '30062', '4/21/1982', '61.3')
# ('1528', '25025120201', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1202.01', '30062', '4/21/1982', '61.3')
# ('1528', '25025120301', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1203.01', '30062', '4/21/1982', '61.3')
# ('1528', '25025120400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1204.0', '30062', '4/21/1982', '61.3')
# ('1528', '25025120500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1205.0', '30062', '4/21/1982', '61.3')
# ('1528', '25025120700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1207.0', '30062', '4/21/1982', '61.3')
# ('1528', '25025120600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1206.0', '30062', '4/21/1982', '61.3')
# ('1528', '25025120103', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1201.03', '30062', '4/21/1982', '61.3')
# ('1526', '25025140400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1404.0', '30062', '4/21/1982', '49.6')
# ('1526', '25025100100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1001.0', '30062', '4/21/1982', '49.6')
# ('1526', '25025100200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1002.0', '30062', '4/21/1982', '49.6')
# ('1526', '25025100300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1003.0', '30062', '4/21/1982', '49.6')
# ('1526', '25025101001', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1010.01', '30062', '4/21/1982', '49.6')
# ('1526', '25025101002', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1010.02', '30062', '4/21/1982', '49.6')
# ('1526', '25025101101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1011.01', '30062', '4/21/1982', '49.6')
# ('1526', '25025101102', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '1011.02', '30062', '4/21/1982', '49.6')
# ('1525', '25025080300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '803.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025081200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '812.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025081300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '813.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025081400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '814.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025081500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '815.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025081700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '817.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025081800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '818.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025081900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '819.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025082000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '820.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025082100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '821.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025090100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '901.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025090200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '902.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025090300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '903.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025091900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '919.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025092300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '923.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025091500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '915.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025091700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '917.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025092400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '924.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025091400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '914.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025090400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '904.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025090600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '906.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025091200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '912.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025091300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '913.0', '30062', '4/21/1982', '39.39')
# ('1525', '25025080100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '801.0', '30062', '4/21/1982', '39.39')
# ('1524', '25025030300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '303.0', '30062', '4/21/1982', '53.1')
# ('1524', '25025030400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '304.0', '30062', '4/21/1982', '53.1')
# ('1524', '25025030500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '305.0', '30062', '4/21/1982', '53.1')
# ('1524', '25025030100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '301.0', '30062', '4/21/1982', '53.1')
# ('1524', '25025030200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '302.0', '30062', '4/21/1982', '53.1')
# ('1521', '25025070101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '701.01', '30062', '4/21/1982', '46.8')
# ('1521', '25025070200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '702.0', '30062', '4/21/1982', '46.8')
# ('1521', '25025070300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '703.0', '30062', '4/21/1982', '46.8')
# ('1521', '25025070402', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '704.02', '30062', '4/21/1982', '46.8')
# ('1521', '25025070500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '705.0', '30062', '4/21/1982', '46.8')
# ('1521', '25025070600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '706.0', '30062', '4/21/1982', '46.8')
# ('1521', '25025070900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '709.0', '30062', '4/21/1982', '46.8')
# ('1521', '25025071101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '711.01', '30062', '4/21/1982', '46.8')
# ('1521', '25025071201', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '712.01', '30062', '4/21/1982', '46.8')
# ('1521', '25025070700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '707.0', '30062', '4/21/1982', '46.8')
# ('1521', '25025981700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9817.0', '30062', '4/21/1982', '46.8')
# ('1521', '25025070800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '708.0', '30062', '4/21/1982', '46.8')
# ('1513', '25025000802', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8.02', '29993', '2/11/1982', '58.8')
# ('1513', '25025000803', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8.03', '29993', '2/11/1982', '58.8')
# ('1513', '25025000701', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7.01', '29993', '2/11/1982', '58.8')
# ('1513', '25025000703', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7.03', '29993', '2/11/1982', '58.8')
# ('1513', '25025000704', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7.04', '29993', '2/11/1982', '58.8')
# ('1513', '25025000401', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4.01', '29993', '2/11/1982', '58.8')
# ('1513', '25025000402', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4.02', '29993', '2/11/1982', '58.8')
# ('1513', '25025000502', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5.02', '29993', '2/11/1982', '58.8')
# ('1513', '25025000503', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5.03', '29993', '2/11/1982', '58.8')
# ('1513', '25025000504', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5.04', '29993', '2/11/1982', '58.8')
# ('1513', '25025000602', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6.02', '29993', '2/11/1982', '58.8')
# ('1544', '25025010500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '105.0', '34520', '7/5/1994', '60.9')
# ('1527', '25025090901', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '909.01', '30062', '4/21/1982', '51.31')
# ('1545', '25013811500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8115.0', '34465', '5/11/1994', '58.8')
# ('1542', '25009260200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2602.0', '34465', '5/11/1994', '60.9')
# ('1540', '25023525300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5253.0', '34465', '5/11/1994', '58.1')
# ('1539', '25017383101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3831.01', '34465', '5/11/1994', '59.9')
# ('1539', '25017383102', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3831.02', '34465', '5/11/1994', '59.9')
# ('1538', '25013801800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8018.0', '34465', '5/11/1994', '54.28')
# ('1538', '25013801901', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8019.01', '34465', '5/11/1994', '54.28')
# ('1538', '25013801902', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8019.02', '34465', '5/11/1994', '54.28')
# ('1538', '25013802000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8020.0', '34465', '5/11/1994', '54.28')
# ('1538', '25013800700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8007.0', '34465', '5/11/1994', '54.28')
# ('1538', '25013800800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8008.0', '34465', '5/11/1994', '54.28')
# ('1538', '25013800900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8009.0', '34465', '5/11/1994', '54.28')
# ('1538', '25013801102', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8011.02', '34465', '5/11/1994', '54.28')
# ('1538', '25013801200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8012.0', '34465', '5/11/1994', '54.28')
# ('1537', '25009210600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2106.0', '31560', '5/28/1986', '60.2')
# ('1537', '25009210700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2107.0', '31560', '5/28/1986', '60.2')
# ('1537', '25009210800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2108.0', '31560', '5/28/1986', '60.2')
# ('1537', '25009210900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2109.0', '31560', '5/28/1986', '60.2')
# ('1531', '25027747101', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7471.01', '34465', '5/11/1994', '58.3')
# ('1531', '25027747102', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7471.02', '34465', '5/11/1994', '58.3')
# ('1531', '25027748100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7481.0', '34465', '5/11/1994', '58.3')
# ('1531', '25027749100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7491.0', '34465', '5/11/1994', '58.3')
# ('1531', '25027749200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '7492.0', '34465', '5/11/1994', '58.3')
# ('7747', '33011000202', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '2.02', '40107', '10/21/2009', '64.1')
# ('7747', '33011000300', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '3.0', '40107', '10/21/2009', '64.1')
# ('7747', '33011002100', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '21.0', '40107', '10/21/2009', '64.1')
# ('7747', '33011002000', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '20.0', '40107', '10/21/2009', '64.1')
# ('2102', '33011010800', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '108.0', '34998', '10/26/1995', '60.7')
# ('2102', '33011010500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '105.0', '34998', '10/26/1995', '60.7')
# ('7688', '33011000600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6.0', '39797', '12/15/2008', '59.3')
# ('7688', '33011001300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '13.0', '39797', '12/15/2008', '59.3')
# ('7688', '33011001400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '14.0', '39797', '12/15/2008', '59.3')
# ('7688', '33011001500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '15.0', '39797', '12/15/2008', '59.3')
# ('7688', '33011001600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '16.0', '39797', '12/15/2008', '59.3')
# ('2112', '33011200400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '2004.0', '34520', '7/5/1994', '43.2')
# ('3049', '44007015300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '153.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007015400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '154.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007010800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '108.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007010900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '109.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007011000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '110.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007011100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '111.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007016000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '160.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007016100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '161.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007016300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '163.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007016400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '164.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007015000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '150.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007015100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '151.0', '34619', '10/12/1994', '60.4')
# ('3049', '44007015200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '152.0', '34619', '10/12/1994', '60.4')
# ('3039', '44007010200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '102.0', '33631', '1/28/1992', '61.9')
# ('3039', '44007010300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '103.0', '33631', '1/28/1992', '61.9')
# ('3039', '44007010400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '104.0', '33631', '1/28/1992', '61.9')
# ('4070', '44003020300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '203.0', '33702', '4/8/1992', '58.3')
# ('3043', '44005040500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '405.0', '33702', '4/8/1992', '60.4')
# ('3043', '44005041100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '411.0', '33702', '4/8/1992', '60.4')
# ('3043', '44005041200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '412.0', '33702', '4/8/1992', '60.4')
# ('3042', '44009051502', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '515.02', '33703', '4/9/1992', '0.0')
# ('3042', '44009051504', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '515.04', '33703', '4/9/1992', '0.0')
# ('3042', '44009990100', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '9901.0', '33703', '4/9/1992', '0.0')
# ('3051', '44007018000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '180.0', '34458', '5/4/1994', '61.9')
# ('3051', '44007018100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '181.0', '34458', '5/4/1994', '61.9')
# ('3051', '44007018300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '183.0', '34458', '5/4/1994', '61.9')
# ('3051', '44007017900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '179.0', '34458', '5/4/1994', '61.9')
# ('3048', '44007001100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '11.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007001200', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '12.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007001000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '10.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007000300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007000400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007000600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007000800', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '8.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007000900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007002500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '25.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007002600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '26.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007002700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '27.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007003100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '31.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007003700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '37.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007001300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '13.0', '30062', '4/21/1982', '54.2')
# ('3048', '44007001400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '14.0', '30062', '4/21/1982', '54.2')
# ('3038', '44007014000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '140.0', '34270', '10/28/1993', '54.3')
# ('3038', '44007014700', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '147.0', '34270', '10/28/1993', '54.3')
# ('3038', '44007014100', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '141.0', '34270', '10/28/1993', '54.3')
# ('3046', '44007012900', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '129.0', '34446', '4/22/1994', '0.0')
# ('3046', '44007013001', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '130.01', '34446', '4/22/1994', '0.0')
# ('3046', '44007013002', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '130.02', '34446', '4/22/1994', '0.0')
# ('3046', '44007013101', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '131.01', '34446', '4/22/1994', '0.0')
# ('3046', '44007013102', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '131.02', '34446', '4/22/1994', '0.0')
# ('3046', '44007013300', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '133.0', '34446', '4/22/1994', '0.0')
# ('3045', '44007012104', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '121.04', '34446', '4/22/1994', '0.0')
# ('3045', '44007012200', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '122.0', '34446', '4/22/1994', '0.0')
# ('3045', '44007012300', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '123.0', '34446', '4/22/1994', '0.0')
# ('3045', '44007012601', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '126.01', '34446', '4/22/1994', '0.0')
# ('3045', '44007012602', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '126.02', '34446', '4/22/1994', '0.0')
# ('3045', '44007012702', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '127.02', '34446', '4/22/1994', '0.0')
# ('3045', '44007012701', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '127.01', '34446', '4/22/1994', '0.0')
# ('3045', '44007012102', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '121.02', '34446', '4/22/1994', '0.0')
# ('3045', '44007012103', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '121.03', '34446', '4/22/1994', '0.0')
# ('3045', '44007012801', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '128.01', '34446', '4/22/1994', '0.0')
# ('3045', '44007012802', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '128.02', '34446', '4/22/1994', '0.0')
# ('3045', '44007012803', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '128.03', '34446', '4/22/1994', '0.0')
# ('3047', '44009050401', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '504.01', '34446', '4/22/1994', '0.0')
# ('3047', '44009050402', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '504.02', '34446', '4/22/1994', '0.0')
# ('3047', '44009050102', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '501.02', '34446', '4/22/1994', '0.0')
# ('3047', '44009050103', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '501.03', '34446', '4/22/1994', '0.0')
# ('3047', '44009050302', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '503.02', '34446', '4/22/1994', '0.0')
# ('3047', '44009050104', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '501.04', '34446', '4/22/1994', '0.0')
# ('3047', '44009050301', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '503.01', '34446', '4/22/1994', '0.0')
# ('3044', '44001030601', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '306.01', '34446', '4/22/1994', '0.0')
# ('3044', '44001030602', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '306.02', '34446', '4/22/1994', '0.0')
# ('3044', '44001030700', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '307.0', '34446', '4/22/1994', '0.0')
# ('3044', '44001030800', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '308.0', '34446', '4/22/1994', '0.0')
# ('3044', '44001030902', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '309.02', '34446', '4/22/1994', '0.0')
# ('3044', '44001030500', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '305.0', '34446', '4/22/1994', '0.0')
# ('3044', '44001030901', 'MUA-GE', 'Medically Underserved Area ?�ô Governor?�Ös Exception', 'D', 'Designated', '309.01', '34446', '4/22/1994', '0.0')
# ('3543', '50007000400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '4.0', '34394', '3/1/1994', '58.0')
# ('3543', '50007000500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '5.0', '34394', '3/1/1994', '58.0')
# ('3543', '50007000300', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '3.0', '34394', '3/1/1994', '58.0')
# ('3543', '50007000600', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '6.0', '34394', '3/1/1994', '58.0')
# ('3543', '50007000900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '9.0', '34394', '3/1/1994', '58.0')
# ('3543', '50007001000', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '10.0', '34394', '3/1/1994', '58.0')
# ('3543', '50007002500', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '25.0', '34394', '3/1/1994', '58.0')
# ('3543', '50007002400', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '24.0', '34394', '3/1/1994', '58.0')
# ('7664', '34027043500', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '435.0', '39595', '5/27/2008', '64.5')
# ('7664', '34027043800', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '438.0', '39595', '5/27/2008', '64.5')
# ('7507', '34015501402', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '5014.02', '38698', '12/12/2005', '59.2')
# ('7507', '34015501403', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '5014.03', '38698', '12/12/2005', '59.2')
# ('7507', '34015501404', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '5014.04', '38698', '12/12/2005', '59.2')
# ('2136', '34013013300', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '133.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '121.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '122.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012300', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '123.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012400', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '124.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012500', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '125.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012600', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '126.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012800', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '128.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013012900', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '129.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013013100', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '131.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013013200', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '132.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013011900', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '119.0', '34817', '4/28/1995', '39.7')
# ('2136', '34013013000', 'MUP', 'Medically Underserved Population', 'D', 'Designated', '130.0', '34817', '4/28/1995', '39.7')
# ('7446', '34011030502', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '305.02', '38309', '11/18/2004', '0.0')
# ('7446', '34011030100', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '301.0', '38309', '11/18/2004', '0.0')
# ('7446', '34011030200', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '302.0', '38309', '11/18/2004', '0.0')
# ('7446', '34011030300', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '303.0', '38309', '11/18/2004', '0.0')
# ('7446', '34011030400', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '304.0', '38309', '11/18/2004', '0.0')
# ('7446', '34011030501', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '305.01', '38309', '11/18/2004', '0.0')
# ('7446', '34011010800', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '108.0', '38309', '11/18/2004', '0.0')
# ('6165', '34023004500', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '45.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004700', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '47.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004400', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '44.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004800', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '48.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004900', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '49.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004000', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '40.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004100', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '41.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004200', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '42.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004300', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '43.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023004600', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '46.0', '36852', '11/22/2000', '0.0')
# ('6165', '34023005000', 'MUP-GE', 'Medically Underserved Population ?�ô Governor?�Ös Exception', 'D', 'Designated', '50.0', '36852', '11/22/2000', '0.0')
# ('7539', '34041030900', 'MUA', 'Medically Underserved Area', 'D', 'Designated', '309.0', '34497', '6/12/1994', '62.0')
# Connection closed

# %%
# print all columns for all tables 
sheet1_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'Address', 'City', 'State_Abbr',
#        'Postal_Code', 'Designation_Date', 'Designation_Last_Update_Date',
#        'Designation_Pop', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc', 'Component_Source_ID',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Geography_ID', 'CountyFIPS', 'County_Name', 'StateCountyFIPS',
#        'State_FIPS', 'State_Abbr_2', 'State_Name', 'Primary_State_Name',
#        'Primary_State_FIPS', 'Primary_HHS_Region_Name',
#        'US_Mexico_Border_County', 'US_Mexico_Border_100km',
#        'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'Geocoding_Primary_X',
#        'Geocoding_Primary_Y', 'Common_City_Name_with_State_Abbr',
#        'Common_Postal_Code', 'Common_County_Name', 'Common_StateCounty_FIPS',
#        'Common_State_Abbr', 'Common_State_Name', 'Common_State_FIPS',
#        'Common_Region_Name', 'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet2_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'State_Abbr', 'Degree_of_Shortage',
#        'Designation_Date', 'Designation_Last_Update_Date', 'Designation_Pop',
#        'Estimated_Underserved_Pop', 'Estimated_Served_Pop', 'Formal_Ratio',
#        'Total_FTE_Clinicians', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'Provider_Ratio_Goal',
#        'Percent_Pop_Below_Poverty', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Component_State_Abbr', 'Component_Designation_Date',
#        'Component_Designation_Date_String',
#        'Component_Designation_Last_Update_Date', 'Geography_ID', 'CountyFIPS',
#        'County_Name', 'StateCountyFIPS', 'State_FIPS', 'State_Abbr_2',
#        'State_Name', 'Primary_State_Name', 'Primary_State_FIPS',
#        'Primary_HHS_Region_Name', 'US_Mexico_Border_County',
#        'US_Mexico_Border_100km', 'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'HPSA_Pop_Type_Code',
#        'HPSA_Pop_Type_Desc', 'HPSA_Resident_Civilian_Pop',
#        'Common_County_Name', 'Common_StateCounty_FIPS', 'Common_State_Abbr',
#        'Common_State_Name', 'Common_State_FIPS', 'Common_Region_Name',
#        'HPSA_Withdrawn_Date', 'HPSA_Withdrawn_Date_String', 'Provider_Type',
#        'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet3_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'Address', 'City', 'State_Abbr',
#        'Postal_Code', 'Designation_Date', 'Designation_Last_Update_Date',
#        'Designation_Pop', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc', 'Component_Source_ID',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Geography_ID', 'CountyFIPS', 'County_Name', 'StateCountyFIPS',
#        'State_FIPS', 'State_Abbr_2', 'State_Name', 'Primary_State_Name',
#        'Primary_State_FIPS', 'Primary_HHS_Region_Name',
#        'US_Mexico_Border_County', 'US_Mexico_Border_100km',
#        'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'Geocoding_Primary_X',
#        'Geocoding_Primary_Y', 'Common_City_Name_with_State_Abbr',
#        'Common_Postal_Code', 'Common_County_Name', 'Common_StateCounty_FIPS',
#        'Common_State_Abbr', 'Common_State_Name', 'Common_State_FIPS',
#        'Common_Region_Name', 'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet4_data.columns
# Out:
# Index(['MUA_SOURCE_ID', 'MUA_AREA_CD', 'MUA_DESIGNATION_TYP_CD',
#        'MUA_DESIGNATION_TYP_DESC', 'MUA_STATUS_CD', 'MUA_STATUS_DESC',
#        'CENSUS_TRACT', 'MUA_DESIGNATION_DT', 'MUA_DESIGNATION_DT_TXT',
#        'MUA_SCORE', 'MUA_SERVICE_AREA_NM', 'MUA_UPDATE_DT',
#        'MUA_UPDATE_DT_TXT', 'US_MEXICO_BORDER_100KM_IND',
#        'US_MEXICO_BORDER_COUNTY_IND', 'STATE_COUNTY_FIPS_CD', 'COUNTY_FIPS_CD',
#        'LIST_BOX_COUNTY_NM', 'COUNTY_NM', 'COUNTY_DESC', 'REGION_CD',
#        'REGION_NM', 'STATE_FIPS_CD', 'STATE_NM', 'STATE_ABBR',
#        'POVERTY_100_PCT_NUM', 'POP_AGE_65_OVER_PCT', 'INFANT_MORTALITY_RATE',
#        'DW_RECORD_CREATE_DT', 'DW_RECORD_CREATE_DT_TXT',
#        'PRIMARY_STATE_FIPS_CD', 'PRIMARY_STATE_ABBR', 'PRIMARY_STATE_NM',
#        'PRIMARY_REGION_CD', 'PRIMARY_REGION_NM', 'CMN_REGION_CD',
#        'CMN_REGION_NM', 'CMN_STATE_NM', 'CMN_STATE_ABBR', 'CMN_STATE_FIPS_CD',
#        'CMN_STATE_COUNTY_FIPS_CD', 'CMN_COUNTY_NM_STATE_ABBR',
#        'BREAK_DESIGNATION_IND', 'MUA_COMP_DESIGNATION_DT',
#        'MUA_COMP_DESIGNATION_DT_TXT', 'MUA_COMP_GEO_NM', 'MUA_COMP_GEO_TYP_CD',
#        'MUA_COMP_GEO_TYP_DESC', 'MUA_COMP_GEO_TYP_ID',
#        'MUA_COMP_LAST_UPDATE_DT', 'MUA_COMP_STATUS_CD', 'MUA_COMP_STATUS_DESC',
#        'MUA_COMP_UPDATE_DT_TXT', 'MUA_DESIGNATION_POP', 'MUA_METRO_IND_CD',
#        'MUA_METRO_IND_DESC', 'MUA_METRO_IND_ID', 'MUA_POPULATION_TYP_CD',
#        'MUA_POPULATION_TYP_DESC', 'MUA_POPULATION_TYP_ID', 'MUA_RES_CIV_POP',
#        'RURAL_STATUS_CD', 'RURAL_STATUS_DESC', 'PROVIDER_1000_POP'],
#       dtype='object')

# %% [markdown]
# ### Usage - Queries Procedures

# %%
# Function to fetch and print tables with headers
def print_tables():
    try:
        conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
        if conn.is_connected():
            cursor = conn.cursor(dictionary=True)

            # Fetch table names
            cursor.execute("SHOW TABLES")
            tables = cursor.fetchall()

            # Print tables with headers
            for table in tables:
                table_name = table['Tables_in_task_x']
                print(f"Table: {table_name}")

                # Fetch and print table data with headers
                cursor.execute(f"SELECT * FROM {table_name}")
                result = cursor.fetchall()

                if result:
                    df = pd.DataFrame(result)
                    print(df)

                print("\n")

    except Error as e:
        print(f"Error: {e}")

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

# Print tables with headers
print_tables()
# Out:
# Table: hpsa_dental_health
#       Source_ID                              Source_Name Status_Code  \
# 0    6409994016              Carl Albert Indian Hospital           W
# 1    6319993124            Winnebago PHS Indian Hospital           W
# 2    6089990849  Southern Colorado Ute Services Unit-Fed           W
# 3    60499904B5   Phx Area Office Two Renaissance Square           W
# 4    6569995629    Ft. Washakie PHS Indian Health Center           D
# ..          ...                                      ...         ...
# 495  6043918770             NA CARDIOLOGY PROG FLAGSTAFF           D
# 496  6043906683                EAST FORK LUTHERAN SCHOOL           D
# 497  6042473681               NAHATA DZIIL HEALTH CENTER           D
# 498  6042421598                   JOHN F. KENNEDY SCHOOL           D
# 499  6042144212            CRADLEBOARD ELEMENTARY SCHOOL           D
#
#     Status_Description Type_Code  \
# 0            Withdrawn       IHS
# 1            Withdrawn       IHS
# 2            Withdrawn       IHS
# 3            Withdrawn       IHS
# 4           Designated       IHS
# ..                 ...       ...
# 495         Designated       ITU
# 496         Designated       ITU
# 497         Designated       ITU
# 498         Designated       ITU
# 499         Designated       ITU
#
#                                              Type_Desc  \
# 0        Indian, Tribal and Urban Indian Organizations
# 1        Indian, Tribal and Urban Indian Organizations
# 2        Indian, Tribal and Urban Indian Organizations
# 3        Indian, Tribal and Urban Indian Organizations
# 4        Indian, Tribal and Urban Indian Organizations
# ..                                                 ...
# 495  Indian Health Service, Tribal Health, and Urba...
# 496  Indian Health Service, Tribal Health, and Urba...
# 497  Indian Health Service, Tribal Health, and Urba...
# 498  Indian Health Service, Tribal Health, and Urba...
# 499  Indian Health Service, Tribal Health, and Urba...
#
#                       Address           City State_Abbr Postal_Code
# 0      1001 N Country Club Rd            Ada         OK  74820-2847
# 1                   PO BOX Hh      Winnebago         NE  68071-0767
# 2               Weeminuche Dr        Ignacio         CO       81137
# 3                100 N 1st St        Phoenix         AZ       85004
# 4                  PO BOX 128  Fort Washakie         WY  82514-0128
# ..                        ...            ...        ...         ...
# 495  1215 N Beaver St Ste 201      Flagstaff         AZ  86001-3126
# 496      4325 Fort Apache Rd.     Whiteriver         AZ       85941
# 497       Chiih'tow Boulevard        Sanders         AZ       86512
# 498      110 W. Dish Chin Rd.     Whiteriver         AZ       85941
# 499        7301 Power Line Rd     Whiteriver         AZ       85941
#
# [500 rows x 10 columns]
#
#
# Table: hpsa_mental_health
#       Source_ID                           Source_Name Status_Code  \
# 0        733007                                  Coos           W
# 1    7449994412  Northern Rhode Island Catchment Area           W
# 2    7449994412  Northern Rhode Island Catchment Area           W
# 3    7449994412  Northern Rhode Island Catchment Area           W
# 4    7449994412  Northern Rhode Island Catchment Area           W
# ..          ...                                   ...         ...
# 495  7469994624                      Catchment Area 7           W
# 496  7469994624                      Catchment Area 7           W
# 497  7469994624                      Catchment Area 7           W
# 498  7469994624                      Catchment Area 7           W
# 499  7469994624                      Catchment Area 7           W
#
#     Status_Description Type_Code        Type_Desc State_Abbr  \
# 0            Withdrawn  Hpsa Geo  Geographic HPSA         NH
# 1            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# 2            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# 3            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# 4            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# ..                 ...       ...              ...        ...
# 495          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 496          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 497          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 498          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 499          Withdrawn  Hpsa Geo  Geographic HPSA         SD
#
#     Degree_of_Shortage Designation_Date Designation_Last_Update_Date
# 0       Not applicable            29005                        37799
# 1       Not applicable            37672                        39671
# 2       Not applicable            37672                        39671
# 3       Not applicable            37672                        39671
# 4       Not applicable            37672                        39671
# ..                 ...              ...                          ...
# 495     Not applicable            36633                        43283
# 496     Not applicable            36633                        43283
# 497     Not applicable            36633                        43283
# 498     Not applicable            36633                        43283
# 499     Not applicable            36633                        43283
#
# [500 rows x 10 columns]
#
#
# Table: hpsa_mua
#     MUA_SOURCE_ID  MUA_AREA_CD MUA_DESIGNATION_TYP_CD  \
# 0             474   9013530200                    MUP
# 1             474   9013530100                    MUP
# 2             470   9005310300                    MUP
# 3             470   9005310500                    MUP
# 4             470   9005310801                    MUP
# ..            ...          ...                    ...
# 495          6165  34023004200                 MUP-GE
# 496          6165  34023004300                 MUP-GE
# 497          6165  34023004600                 MUP-GE
# 498          6165  34023005000                 MUP-GE
# 499          7539  34041030900                    MUA
#
#                               MUA_DESIGNATION_TYP_DESC MUA_STATUS_CD  \
# 0                     Medically Underserved Population             D
# 1                     Medically Underserved Population             D
# 2                     Medically Underserved Population             D
# 3                     Medically Underserved Population             D
# 4                     Medically Underserved Population             D
# ..                                                 ...           ...
# 495  Medically Underserved Population ?�ô Governor?...             D
# 496  Medically Underserved Population ?�ô Governor?...             D
# 497  Medically Underserved Population ?�ô Governor?...             D
# 498  Medically Underserved Population ?�ô Governor?...             D
# 499                         Medically Underserved Area             D
#
#     MUA_STATUS_DESC CENSUS_TRACT MUA_DESIGNATION_DT MUA_DESIGNATION_DT_TXT  \
# 0        Designated       5302.0              34676              12/8/1994
# 1        Designated       5301.0              34676              12/8/1994
# 2        Designated       3103.0              34676              12/8/1994
# 3        Designated       3105.0              34676              12/8/1994
# 4        Designated      3108.01              34676              12/8/1994
# ..              ...          ...                ...                    ...
# 495      Designated         42.0              36852             11/22/2000
# 496      Designated         43.0              36852             11/22/2000
# 497      Designated         46.0              36852             11/22/2000
# 498      Designated         50.0              36852             11/22/2000
# 499      Designated        309.0              34497              6/12/1994
#
#     MUA_SCORE
# 0        47.8
# 1        47.8
# 2        41.1
# 3        41.1
# 4        41.1
# ..        ...
# 495       0.0
# 496       0.0
# 497       0.0
# 498       0.0
# 499      62.0
#
# [500 rows x 10 columns]
#
#
# Table: hpsa_primary_care
#       Source_ID                                  Source_Name Status_Code  \
# 0    1569995651        Ft. Washakie PHS Indian Health Center           D
# 1    1469994698  McLaughlin PHS Indian Medical/Dental Clinic           D
# 2    1469994687                   Wagner PHS Indian Hospital           D
# 3    141999413V                         Portland Area Office           D
# 4    14099940N2                        Shawnee Health Center           D
# ..          ...                                          ...         ...
# 495  10299902AE                     Saint Paul Health Center           D
# 496  10299902AD                        Karluk Village Clinic           D
# 497  10299902AC                        Little Diomede Clinic           D
# 498  10299902AB                       Eklutna Village Clinic           D
# 499  1029990297                        Tyonek Village Clinic           D
#
#     Status_Description Type_Code  \
# 0           Designated       IHS
# 1           Designated       IHS
# 2           Designated       IHS
# 3           Designated       IHS
# 4           Designated       IHS
# ..                 ...       ...
# 495         Designated       ITU
# 496         Designated       ITU
# 497         Designated       ITU
# 498         Designated       ITU
# 499         Designated       ITU
#
#                                              Type_Desc  \
# 0        Indian, Tribal and Urban Indian Organizations
# 1        Indian, Tribal and Urban Indian Organizations
# 2        Indian, Tribal and Urban Indian Organizations
# 3        Indian, Tribal and Urban Indian Organizations
# 4        Indian, Tribal and Urban Indian Organizations
# ..                                                 ...
# 495  Indian Health Service, Tribal Health, and Urba...
# 496  Indian Health Service, Tribal Health, and Urba...
# 497  Indian Health Service, Tribal Health, and Urba...
# 498  Indian Health Service, Tribal Health, and Urba...
# 499  Indian Health Service, Tribal Health, and Urba...
#
#                       Address               City State_Abbr Postal_Code
# 0                  PO BOX 128      Fort Washakie         WY  82514-0128
# 1               611 2nd Ave E        Mc Laughlin         SD       57642
# 2       110 Washington Ave NW             Wagner         SD       57380
# 3     1220 SW 3rd Ave Ste 476           Portland         OR  97204-2825
# 4       2307 Gordon Cooper Dr            Shawnee         OK  74801-9007
# ..                        ...                ...        ...         ...
# 495       1000 Polivenia Tpke  Saint Paul Island         AK       99660
# 496          26 Alex Brown St             Karluk         AK       99608
# 497                      None               Nome         AK       99762
# 498  26339 Eklutna Village Rd            Chugiak         AK  99567-5148
# 499                   73 C St             Tyonek         AK       99682
#
# [500 rows x 10 columns]

# %%
import mysql.connector
from mysql.connector import Error

# Database connection details
host = 'localhost'
user = 'fr34k'
password = '1391'
database = 'task_x'

# Function to create stored procedures
def create_stored_procedures():
    try:
        conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
        if conn.is_connected():
            cursor = conn.cursor()

            # Stored Procedure 1: Get data from hpsa_primary_care
            sp1_query = """
                CREATE PROCEDURE GetPrimaryCareData()
                BEGIN
                    SELECT * FROM hpsa_primary_care;
                END
            """
            cursor.execute(sp1_query)
            print("Stored Procedure 1 created successfully.")

            # Stored Procedure 2: Get data from hpsa_dental_health
            sp2_query = """
                CREATE PROCEDURE GetDentalHealthData()
                BEGIN
                    SELECT * FROM hpsa_dental_health;
                END
            """
            cursor.execute(sp2_query)
            print("Stored Procedure 2 created successfully.")

            # Commit the changes
            conn.commit()

    except Error as e:
        print(f"Error: {e}")

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

# Create stored procedures
create_stored_procedures()
# Out:
# Error: 1304 (42000): PROCEDURE GetPrimaryCareData already exists

# %% [markdown]
# ![image3](image3.png)

# %%
import pandas as pd

# Function to execute queries and print results
def execute_queries():
    try:
        conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
        if conn.is_connected():
            cursor = conn.cursor(dictionary=True)

            # Query 1: Get unique cities from hpsa_primary_care
            query1 = "SELECT DISTINCT City FROM hpsa_primary_care;"
            result1 = pd.read_sql(query1, conn)
            print("Query 1:")
            print(result1)

            # Query 2: Get the count of each Type_Desc from hpsa_dental_health
            query2 = "SELECT Type_Desc, COUNT(*) as Count FROM hpsa_dental_health GROUP BY Type_Desc;"
            result2 = pd.read_sql(query2, conn)
            print("\nQuery 2:")
            print(result2)
            
            # Query 3: Get the average MUA_SCORE for each MUA_STATUS_DESC in hpsa_mua
            query3 = "SELECT MUA_STATUS_DESC, AVG(MUA_SCORE) as Average_Score FROM hpsa_mua GROUP BY MUA_STATUS_DESC;"
            result3 = pd.read_sql(query3, conn)
            print("\nQuery 3:")
            print(result3)

                        
            query4 = """
                SELECT Source_Name, Address
                FROM hpsa_primary_care
                ORDER BY Address DESC
                LIMIT 5;
            """
            result4 = pd.read_sql(query4, conn)
            print("\nQuery 4:")
            print(result4)


    except Error as e:
        print(f"Error: {e}")

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

# Execute queries
execute_queries()
# Out:
# Query 1:
#                   City
# 0        Fort Washakie
# 1          Mc Laughlin
# 2               Wagner
# 3             Portland
# 4              Shawnee
# ..                 ...
# 408  Saint Paul Island
# 409             Karluk
# 410               Nome
# 411            Chugiak
# 412             Tyonek
#
# [413 rows x 1 columns]
#
# Query 2:
#                                            Type_Desc  Count
# 0  Indian Health Service, Tribal Health, and Urba...    474
# 1      Indian, Tribal and Urban Indian Organizations     26
#
# Query 3:
#   MUA_STATUS_DESC  Average_Score
# 0      Designated       47.70276
#
# Query 4:
#                 Source_Name                                      Address
# 0     COCHITI DENTAL CLINIC                                  Windmill Rd
# 1            WHITE HORSE HS                     Whitehorse Road/County 4
# 2    K'ima:w Medical Center  Weitchpec Route, Libby Nix Community Center
# 3  CANNONBAL HEALTH STATION                                    Weasel St
# 4    WAKPALA HEALTH STATION                                 Wakpala Road
# <ipython-input-16-dbb724126fca>:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result1 = pd.read_sql(query1, conn)
# <ipython-input-16-dbb724126fca>:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result2 = pd.read_sql(query2, conn)
# <ipython-input-16-dbb724126fca>:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result3 = pd.read_sql(query3, conn)
# <ipython-input-16-dbb724126fca>:35: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result4 = pd.read_sql(query4, conn)

# %% [markdown]
# ### Conclusion:
# The project successfully leverages Python and MySQL to initialize and populate a database with four tables (hpsa_primary_care, hpsa_mental_health, hpsa_dental_health, and hpsa_mua). The script utilizes the pandas library to handle datasets, dynamically generates SQL queries for table creation and data insertion, and ensures proper error handling and connection closure.
#
# The database is structured to store information related to healthcare provider shortage areas, mental health designations, dental health designations, and medically underserved areas. This organized data lays the foundation for efficient querying and analysis.
#
# Additionally, the script includes functionality to perform user-defined SELECT queries, allowing users to retrieve specific information from the populated tables interactively.
#
# Overall, the project combines data management, database creation, and user interaction, providing a robust foundation for further development and analysis in the realm of healthcare data.
