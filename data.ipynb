# %% [markdown]
# ### Introduction
#
# The application idea revolves around managing and analyzing healthcare workforce data, specifically focusing on Health Professional Shortage Areas (HPSAs) and Medically Underserved Areas (MUAs). The data source is a set of tables representing these areas, obtained from reliable healthcare databases or government health agencies.
#
# The primary goal of the application is to provide insights into the distribution and characteristics of healthcare resources across different regions. It aims to assist healthcare planners, policymakers, and researchers in making informed decisions about resource allocation, identifying areas with shortages, and addressing healthcare disparities.
#
# The core data includes information about various health facilities, their designations, and the status of different HPSAs and MUAs. This data is crucial for understanding the availability of healthcare services in different geographical areas. The application can be a valuable tool for optimizing workforce distribution, improving access to care, and ultimately enhancing overall health outcomes.
#
# The database schema is designed to capture essential information about Health Professional Shortage Areas (HPSAs) and Medically Underserved Areas (MUAs). Here's a brief overview of the schema:
#
# ### Tables:
# hpsa_primary_care:
#
#     Source_ID (Primary Key)
#     Source_Name
#     Status_Code
#     Status_Description
#     Type_Code
#     Type_Desc
#     Address
#     City
#     State_Abbr
#     Postal_Code
#
# hpsa_mental_health:
#
#     Source_ID (Primary Key)
#     Source_Name
#     Status_Code
#     Status_Description
#     Type_Code
#     Type_Desc
#     State_Abbr
#     Degree_of_Shortage
#     Designation_Date
#     Designation_Last_Update_Date
#
# hpsa_dental_health:
#
#     Source_ID (Primary Key)
#     Source_Name
#     Status_Code
#     Status_Description
#     Type_Code
#     Type_Desc
#     Address
#     City
#     State_Abbr
#     Postal_Code
#
# hpsa_mua:
#
#     MUA_SOURCE_ID (Primary Key)
#     MUA_AREA_CD
#     MUA_DESIGNATION_TYP_CD
#     MUA_DESIGNATION_TYP_DESC
#     MUA_STATUS_CD
#     MUA_STATUS_DESC
#     CENSUS_TRACT
#     MUA_DESIGNATION_DT
#     MUA_DESIGNATION_DT_TXT
#     MUA_SCORE
# ### Rationale:
# - Normalization: The schema follows normalization principles to minimize data redundancy and improve data integrity.
#
# - Primary Keys: Each table has a primary key to uniquely identify records.
#
# Consistent Naming: Column names are consistent across tables for similar attributes, facilitating ease of understanding and query writing.
#
# Relationships: While the schema presented here doesn't explicitly show foreign keys, they would be used to establish relationships between tables, ensuring data consistency.
#
# This schema allows for efficient querying and analysis of healthcare workforce data, providing a foundation for the application's functionality.

# %%
import pandas as pd

import mysql.connector
from mysql.connector import Error

# Read the Excel file
filename = 'data.xlsx'
xls = pd.ExcelFile(filename)

# Get the sheet names
sheet_names = xls.sheet_names

# Create a dictionary to store the datasets
datasets = {}

# Loop through each sheet and save the data as a dataset
for sheet_name in sheet_names:
    dataset = pd.read_excel(filename, sheet_name=sheet_name)
    
    # Remove columns with NaN values
    dataset = dataset.dropna(axis=1, how='all')
    
    # Replace NaN values with None
    dataset = dataset.replace(to_replace=float('nan'), value=None)
    
    # Convert columns to appropriate types if needed
    # dataset['column_name'] = pd.to_numeric(dataset['column_name'], errors='coerce')
    
    datasets[sheet_name] = dataset

# Access a specific dataset
sheet1_data = datasets['hpsa_primary_care'] 
sheet2_data = datasets['hpsa_mental_health'] 
sheet3_data = datasets['hpsa_dental_health']
sheet4_data = datasets['hpsa_mua']

# %%
sheet1_data.head()
# Out:
#     Source_ID                                  Source_Name Status_Code  \
# 0  1569995651        Ft. Washakie PHS Indian Health Center           D
# 1  1469994698  McLaughlin PHS Indian Medical/Dental Clinic           D
# 2  1469994687                   Wagner PHS Indian Hospital           D
# 3  141999413V                         Portland Area Office           D
# 4  14099940N2                        Shawnee Health Center           D
#
#   Status_Description Type_Code                                      Type_Desc  \
# 0         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 1         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 2         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 3         Designated       IHS  Indian, Tribal and Urban Indian Organizations
# 4         Designated       IHS  Indian, Tribal and Urban Indian Organizations
#
#                    Address           City State_Abbr Postal_Code  ...  \
# 0               PO BOX 128  Fort Washakie         WY  82514-0128  ...
# 1            611 2nd Ave E    Mc Laughlin         SD       57642  ...
# 2    110 Washington Ave NW         Wagner         SD       57380  ...
# 3  1220 SW 3rd Ave Ste 476       Portland         OR  97204-2825  ...
# 4    2307 Gordon Cooper Dr        Shawnee         OK  74801-9007  ...
#
#    Common_Postal_Code       Common_County_Name Common_StateCounty_FIPS  \
# 0               82514       Fremont County, WY                   56013
# 1               57642        Corson County, SD                   46031
# 2               57380   Charles Mix County, SD                   46023
# 3               97204     Multnomah County, OR                   41051
# 4               74801  Pottawatomie County, OK                   40125
#
#   Common_State_Abbr Common_State_Name  Common_State_FIPS Common_Region_Name  \
# 0                WY           Wyoming                 56        Region VIII
# 1                SD      South Dakota                 46        Region VIII
# 2                SD      South Dakota                 46        Region VIII
# 3                OR            Oregon                 41           Region X
# 4                OK          Oklahoma                 40          Region VI
#
#    Rural_Status_Code Rural_Status_Desc  \
# 0                  R             Rural
# 1                  R             Rural
# 2                  R             Rural
# 3                  N         Non-Rural
# 4                  R             Rural
#
#                   HPSA_Designation_Pop_Type_Desc
# 0  Indian, Tribal and Urban Indian Organizations
# 1  Indian, Tribal and Urban Indian Organizations
# 2  Indian, Tribal and Urban Indian Organizations
# 3  Indian, Tribal and Urban Indian Organizations
# 4  Indian, Tribal and Urban Indian Organizations
#
# [5 rows x 55 columns]

# %%
sheet2_data.head()

# %%
sheet3_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'Address', 'City', 'State_Abbr',
#        'Postal_Code', 'Designation_Date', 'Designation_Last_Update_Date',
#        'Designation_Pop', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc', 'Component_Source_ID',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Geography_ID', 'CountyFIPS', 'County_Name', 'StateCountyFIPS',
#        'State_FIPS', 'State_Abbr_2', 'State_Name', 'Primary_State_Name',
#        'Primary_State_FIPS', 'Primary_HHS_Region_Name',
#        'US_Mexico_Border_County', 'US_Mexico_Border_100km',
#        'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'Geocoding_Primary_X',
#        'Geocoding_Primary_Y', 'Common_City_Name_with_State_Abbr',
#        'Common_Postal_Code', 'Common_County_Name', 'Common_StateCounty_FIPS',
#        'Common_State_Abbr', 'Common_State_Name', 'Common_State_FIPS',
#        'Common_Region_Name', 'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet3_data.head()
# Out:
#     Source_ID                              Source_Name Status_Code  \
# 0  6409994016              Carl Albert Indian Hospital           W
# 1  6319993124            Winnebago PHS Indian Hospital           W
# 2  6089990849  Southern Colorado Ute Services Unit-Fed           W
# 3  60499904B5   Phx Area Office Two Renaissance Square           W
# 4  6569995629    Ft. Washakie PHS Indian Health Center           D
#
#   Status_Description Type_Code                                      Type_Desc  \
# 0          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 1          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 2          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 3          Withdrawn       IHS  Indian, Tribal and Urban Indian Organizations
# 4         Designated       IHS  Indian, Tribal and Urban Indian Organizations
#
#                   Address           City State_Abbr Postal_Code  ...  \
# 0  1001 N Country Club Rd            Ada         OK  74820-2847  ...
# 1               PO BOX Hh      Winnebago         NE  68071-0767  ...
# 2           Weeminuche Dr        Ignacio         CO       81137  ...
# 3            100 N 1st St        Phoenix         AZ       85004  ...
# 4              PO BOX 128  Fort Washakie         WY  82514-0128  ...
#
#    Common_Postal_Code   Common_County_Name Common_StateCounty_FIPS  \
# 0               74820  Pontotoc County, OK                   40123
# 1               68071  Thurston County, NE                   31173
# 2               81137  La Plata County, CO                    8067
# 3               85004  Maricopa County, AZ                    4013
# 4               82514   Fremont County, WY                   56013
#
#   Common_State_Abbr Common_State_Name  Common_State_FIPS Common_Region_Name  \
# 0                OK          Oklahoma                 40          Region VI
# 1                NE          Nebraska                 31         Region VII
# 2                CO          Colorado                  8        Region VIII
# 3                AZ           Arizona                  4          Region IX
# 4                WY           Wyoming                 56        Region VIII
#
#    Rural_Status_Code Rural_Status_Desc  \
# 0                  R             Rural
# 1                  R             Rural
# 2                  R             Rural
# 3                  N         Non-Rural
# 4                  R             Rural
#
#                   HPSA_Designation_Pop_Type_Desc
# 0  Indian, Tribal and Urban Indian Organizations
# 1  Indian, Tribal and Urban Indian Organizations
# 2  Indian, Tribal and Urban Indian Organizations
# 3  Indian, Tribal and Urban Indian Organizations
# 4  Indian, Tribal and Urban Indian Organizations
#
# [5 rows x 55 columns]

# %%
sheet4_data.columns
# Out:
# Index(['MUA_SOURCE_ID', 'MUA_AREA_CD', 'MUA_DESIGNATION_TYP_CD',
#        'MUA_DESIGNATION_TYP_DESC', 'MUA_STATUS_CD', 'MUA_STATUS_DESC',
#        'CENSUS_TRACT', 'MUA_DESIGNATION_DT', 'MUA_DESIGNATION_DT_TXT',
#        'MUA_SCORE', 'MUA_SERVICE_AREA_NM', 'MUA_UPDATE_DT',
#        'MUA_UPDATE_DT_TXT', 'US_MEXICO_BORDER_100KM_IND',
#        'US_MEXICO_BORDER_COUNTY_IND', 'STATE_COUNTY_FIPS_CD', 'COUNTY_FIPS_CD',
#        'LIST_BOX_COUNTY_NM', 'COUNTY_NM', 'COUNTY_DESC', 'REGION_CD',
#        'REGION_NM', 'STATE_FIPS_CD', 'STATE_NM', 'STATE_ABBR',
#        'POVERTY_100_PCT_NUM', 'POP_AGE_65_OVER_PCT', 'INFANT_MORTALITY_RATE',
#        'DW_RECORD_CREATE_DT', 'DW_RECORD_CREATE_DT_TXT',
#        'PRIMARY_STATE_FIPS_CD', 'PRIMARY_STATE_ABBR', 'PRIMARY_STATE_NM',
#        'PRIMARY_REGION_CD', 'PRIMARY_REGION_NM', 'CMN_REGION_CD',
#        'CMN_REGION_NM', 'CMN_STATE_NM', 'CMN_STATE_ABBR', 'CMN_STATE_FIPS_CD',
#        'CMN_STATE_COUNTY_FIPS_CD', 'CMN_COUNTY_NM_STATE_ABBR',
#        'BREAK_DESIGNATION_IND', 'MUA_COMP_DESIGNATION_DT',
#        'MUA_COMP_DESIGNATION_DT_TXT', 'MUA_COMP_GEO_NM', 'MUA_COMP_GEO_TYP_CD',
#        'MUA_COMP_GEO_TYP_DESC', 'MUA_COMP_GEO_TYP_ID',
#        'MUA_COMP_LAST_UPDATE_DT', 'MUA_COMP_STATUS_CD', 'MUA_COMP_STATUS_DESC',
#        'MUA_COMP_UPDATE_DT_TXT', 'MUA_DESIGNATION_POP', 'MUA_METRO_IND_CD',
#        'MUA_METRO_IND_DESC', 'MUA_METRO_IND_ID', 'MUA_POPULATION_TYP_CD',
#        'MUA_POPULATION_TYP_DESC', 'MUA_POPULATION_TYP_ID', 'MUA_RES_CIV_POP',
#        'RURAL_STATUS_CD', 'RURAL_STATUS_DESC', 'PROVIDER_1000_POP'],
#       dtype='object')

# %%
sheet4_data.head()
# Out:
#    MUA_SOURCE_ID  MUA_AREA_CD MUA_DESIGNATION_TYP_CD  \
# 0            474   9013530200                    MUP
# 1            474   9013530100                    MUP
# 2            470   9005310300                    MUP
# 3            470   9005310500                    MUP
# 4            470   9005310801                    MUP
#
#            MUA_DESIGNATION_TYP_DESC MUA_STATUS_CD MUA_STATUS_DESC  \
# 0  Medically Underserved Population             D      Designated
# 1  Medically Underserved Population             D      Designated
# 2  Medically Underserved Population             D      Designated
# 3  Medically Underserved Population             D      Designated
# 4  Medically Underserved Population             D      Designated
#
#    CENSUS_TRACT  MUA_DESIGNATION_DT MUA_DESIGNATION_DT_TXT  MUA_SCORE  ...  \
# 0       5302.00               34676              12/8/1994       47.8  ...
# 1       5301.00               34676              12/8/1994       47.8  ...
# 2       3103.00               34676              12/8/1994       41.1  ...
# 3       3105.00               34676              12/8/1994       41.1  ...
# 4       3108.01               34676              12/8/1994       41.1  ...
#
#   MUA_METRO_IND_CD  MUA_METRO_IND_DESC MUA_METRO_IND_ID MUA_POPULATION_TYP_CD  \
# 0                0             Unknown                0                    LI
# 1                0             Unknown                0                    LI
# 2                0             Unknown                0                    LI
# 3                0             Unknown                0                    LI
# 4                0             Unknown                0                    LI
#
#   MUA_POPULATION_TYP_DESC  MUA_POPULATION_TYP_ID  MUA_RES_CIV_POP  \
# 0          MUP Low Income                      2             None
# 1          MUP Low Income                      2             None
# 2          MUP Low Income                      2             None
# 3          MUP Low Income                      2             None
# 4          MUP Low Income                      2             None
#
#   RURAL_STATUS_CD RURAL_STATUS_DESC PROVIDER_1000_POP
# 0               N         Non-Rural              None
# 1               N         Non-Rural              None
# 2               R             Rural              None
# 3               R             Rural              None
# 4               R             Rural              None
#
# [5 rows x 64 columns]

# %% [markdown]
# ### Stored Procedures:
# 1. usp_GetAverageScoreByMUAStatus
# Purpose: This stored procedure calculates and returns the average MUA score for each MUA status.
#
# - How it works:
# ```
# CREATE PROCEDURE usp_GetAverageScoreByMUAStatus
#     AS
#     BEGIN
#         SELECT
#             MUA_STATUS_DESC,
#             AVG(CAST(MUA_SCORE AS FLOAT)) AS Average_Score
#         FROM
#             hpsa_mua
#         GROUP BY
#             MUA_STATUS_DESC;
#     END;
# ```
# - Usage in Application:
# This procedure provides a quick overview of the average MUA scores based on different MUA statuses. It aids in identifying trends and disparities in healthcare accessibility across various designations.
#
# 2. usp_GetHPSAByStateAndType
# Purpose: This stored procedure retrieves HPSAs based on the provided state abbreviation and type code.
#
# How it works:
# ```
# CREATE PROCEDURE usp_GetHPSAByStateAndType
#     @StateAbbreviation NVARCHAR(2),
#     @TypeCode NVARCHAR(10)
# AS
# BEGIN
#     SELECT *
#     FROM
#         hpsa_primary_care
#     WHERE
#         State_Abbr = @StateAbbreviation
#         AND Type_Code = @TypeCode;
# END;
# ```
# - Usage in Application:
# It allows the application to fetch specific HPSAs based on user-inputted criteria, helping healthcare planners to focus on areas of interest and address shortages effectively.
#
# ![image1](image1.png)
#
#
# ### Queries
# 1. Average Score of Designated MUAs:
# Purpose: To retrieve the average MUA score for designated areas.
# ```
# SELECT
#     MUA_STATUS_DESC,
#     AVG(CAST(MUA_SCORE AS FLOAT)) AS Average_Score
# FROM
#     hpsa_mua
# WHERE
#     MUA_STATUS_DESC = 'Designated'
# GROUP BY
#     MUA_STATUS_DESC;
# ```
# 2. HPSAs in a Specific State and Type:
# Purpose: To fetch HPSAs in a particular state and of a specific type.
# ```
# SELECT *
# FROM
#     hpsa_primary_care
# WHERE
#     State_Abbr = 'CA'
#     AND Type_Code = 'IHS';
# ```
#
# 3. Designated Mental Health HPSAs:
# Purpose: To retrieve information about designated mental health HPSAs.
#
# ```
# SELECT *
# FROM
#     hpsa_mental_health
# WHERE
#     Status_Description = 'Designated';
# ```
#
# 4. MUAs with the Highest Scores:
# Purpose: To find MUAs with the highest scores.
#
# ```
# SELECT TOP 5
#     *
# FROM
#     hpsa_mua
# ORDER BY
#     MUA_SCORE DESC;
# ```
#
# How they are used in Application:
#
# - The average MUA score query aids in displaying a summary of MUA scores.
# - The HPSA retrieval query allows users to explore specific HPSAs based on state and type.
# - The designated mental health HPSAs query provides insights into areas specifically designated for mental health.
# - The query for MUAs with the highest scores helps identify areas with the greatest need for attention and resources.
# - These queries and procedures collectively empower the application to offer detailed insights into healthcare workforce distribution and shortages, supporting informed decision-making.
#
# ![image4](image4.png)

# %% [markdown]
# - Database Connection:
#
# Attempts to connect to a MySQL database using the provided host, user, password, and database information.
# - Table Creation and Data Insertion:
#
# Defines four datasets, each representing a table (hpsa_primary_care, hpsa_mental_health, hpsa_dental_health, and hpsa_mua).
# For each dataset, it dynamically generates a CREATE TABLE query based on the column names and their types (assumed VARCHAR(255)).
# Executes the CREATE TABLE query to create a table in the MySQL database.
# Prepares and executes an INSERT query to insert the data from the dataset into the corresponding table.
# - Commit Changes:
#
# Commits the changes to the database. This step is crucial for the changes to take effect permanently.
# - Error Handling:
#
# If any error occurs during the process (such as a connection error, SQL syntax error, etc.), it prints an error message.
# - Connection Closure:
#
# Closes the cursor and the database connection, ensuring proper cleanup.
# This script is designed to initialize a MySQL database by creating tables based on provided datasets and inserting data into these tables. It's a common approach when setting up a database for the first time or when updating the schema with new data.
#
# ![image5](image5.png)

# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error

# Database connection details
host = 'localhost'
user = 'fr34k'
password = '1391'
database = 'task_x'

# Create a MySQL connection
try:
    conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
    if conn.is_connected():
        print('Connected to MySQL database')

        # Create a cursor
        cursor = conn.cursor()

        # Drop tables if they exist
        cursor.execute("DROP TABLE IF EXISTS hpsa_primary_care")
        cursor.execute("DROP TABLE IF EXISTS hpsa_mental_health")
        cursor.execute("DROP TABLE IF EXISTS hpsa_dental_health")
        cursor.execute("DROP TABLE IF EXISTS hpsa_mua")

        # Insert datasets into MySQL tables
        datasets = [(sheet1_data.iloc[:, :10], 'hpsa_primary_care'), 
                    (sheet2_data.iloc[:, :10], 'hpsa_mental_health'),
                    (sheet3_data.iloc[:, :10], 'hpsa_dental_health'), 
                    (sheet4_data.iloc[:, :10], 'hpsa_mua')]

        for dataset, table_name in datasets:
            column_names = list(dataset.columns)
            values = dataset.values.tolist()

            # Generate column definitions with types
            column_definitions = ', '.join([f'{column} VARCHAR(255)' for column in column_names])

            # Create table with column names and types
            create_table_query = f"CREATE TABLE {table_name} ({column_definitions})"
            cursor.execute(create_table_query)

            placeholders = ', '.join(['%s'] * len(column_names))

            # Insert data into table
            insert_query = f"INSERT INTO {table_name} ({', '.join(column_names)}) VALUES ({placeholders})"
            cursor.executemany(insert_query, values)

        # Commit the changes
        conn.commit()
        print('Data inserted into MySQL tables')

except Error as e:
    print(f"Error: {e}")

finally:
    # Close the cursor and connection
    if conn.is_connected():
        cursor.close()
        conn.close()
        print('You can now select from tables')
# Out:
# Connected to MySQL database
# Data inserted into MySQL tables
# You can now select from tables

# %% [markdown]
# This Python code establishes a connection to a MySQL database using the mysql.connector library. It prompts the user to input a SQL query, then executes the query and fetches all rows from the result. Finally, it prints each row to the console.
#
# Here's a breakdown:
#
# - Database Connection:
#
# It attempts to connect to a MySQL database using the provided host, user, password, and database information.
#
# - User Input:
#
# The user is prompted to enter a SQL query they want to perform on the connected database.
#
# - Query Execution:
#
# The provided SQL query is executed using the database cursor.
# - Fetching and Printing Rows:
#
# All rows resulting from the query execution are fetched.
# Each row is printed to the console.
# - Error Handling:
#
# If any error occurs during the process, it prints an error message.
# - Connection Closure:
#
# Finally, it closes the cursor and the database connection.
# This code allows users to interactively input and execute SQL queries on the connected MySQL database, providing a flexible way to explore and retrieve data.
# ![image2](image2.png)

# %%
# Create a MySQL connection
try:
    conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
    if conn.is_connected():
        print('Connected to MySQL database')

        # Create a cursor
        cursor = conn.cursor()

        # Select all rows from a table
        select_query = input(str("Enter a query to perform: ")) #"SELECT * FROM hpsa_mua where hpsa_mua.mua_source_ID > 1000;"
        cursor.execute(select_query)

        # Fetch all rows
        rows = cursor.fetchall()

        # Print the rows
        for row in rows:
            print(row)

except Error as e:
    print(f"Error: {e}")

finally:
    # Close the cursor and connection
    if conn.is_connected():
        cursor.close()
        conn.close()
        print('Connection closed')
# Out:
# Connected to MySQL database
# ('6409994016', 'Carl Albert Indian Hospital', 'W', 'Withdrawn', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '1001 N Country Club Rd', 'Ada', 'OK', '74820-2847')
# ('6319993124', 'Winnebago PHS Indian Hospital', 'W', 'Withdrawn', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'PO BOX Hh', 'Winnebago', 'NE', '68071-0767')
# ('6089990849', 'Southern Colorado Ute Services Unit-Fed', 'W', 'Withdrawn', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'Weeminuche Dr', 'Ignacio', 'CO', '81137')
# ('60499904B5', 'Phx Area Office Two Renaissance Square', 'W', 'Withdrawn', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '100 N 1st St', 'Phoenix', 'AZ', '85004')
# ('6569995629', 'Ft. Washakie PHS Indian Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'PO BOX 128', 'Fort Washakie', 'WY', '82514-0128')
# ('6469994643', 'Wagner PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '110 Washington Ave NW', 'Wagner', 'SD', '57380')
# ('6469994623', 'Fort Thompson PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'PO BOX 200', 'Fort Thompson', 'SD', '57339-0200')
# ('6469994619', 'McLaughlin PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '6th St E', 'Mc Laughlin', 'SD', '57642')
# ('6469994616', 'Rosebud PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'BIA Route 1, Solider Creek Road', 'Rosebud', 'SD', '57570-0400')
# ('640999409M', 'Okmulgee Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '1313 E 20th St', 'Okmulgee', 'OK', '74447-6303')
# ('640999409I', 'Wilma P. Mankiller Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'RR 1 BOX East', 'Stilwell', 'OK', '74960-9801')
# ('640999409D', 'Shawnee Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '2307 Gordon Cooper Dr', 'Shawnee', 'OK', '74801-9007')
# ('6389993830', 'Spirit Lake Tribe', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '74th Ave NE', 'Fort Totten', 'ND', '58335')
# ('6389993810', 'Fort Totten PHS Indian Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'PO BOX 200', 'Fort Totten', 'ND', '58335-0200')
# ('6389993809', 'Fort Berthold PHS Indian Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '1 Minni Tohe Dr', 'New Town', 'ND', '58763-4400')
# ('635999355M', 'Pueblo of Laguna of Community Health and Wellness', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '10 San Jose', 'Laguna', 'NM', '87026')
# ('6359993536', 'Sante Fe PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '1700 Cerrillos Rd', 'Santa Fe', 'NM', '87505-3026')
# ('6329993244', 'Fort McDermitt Tribal Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'N Reservation Rd', 'Paradise Valley', 'NV', '89426')
# ('6329993243', 'Owyhee Community Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '515 Shoshone Cir', 'Elko', 'NV', '89801-5072')
# ('6329993241', 'Elko Health Center', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '515 Shoshone Cir', 'Elko', 'NV', '89801-5072')
# ('630999304P', 'Crow-Lodge Grass Clinic', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'Harding Ave', 'Lodge Grass', 'MT', '59050')
# ('630999304J', 'Fort Belknap PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '456 Gros Ventre Ave', 'Harlem', 'MT', '59526-8044')
# ('6309993023', 'Crow Agency PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '100 Hospital Loop', 'Crow Agency', 'MT', '59022')
# ('60499904EW', 'White Mountain Apache Tribe', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', '301 W Ponderosa St', 'Whiteriver', 'AZ', '85941')
# ('6049990488', 'San Carlos PHS Indian Hospital', 'D', 'Designated', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'PO BOX 208', 'San Carlos', 'AZ', '85550-0208')
# ('6049990492', 'Fort Yuma PHS Indian Hospital', 'W', 'Withdrawn', 'IHS', 'Indian, Tribal and Urban Indian Organizations', 'PO BOX 1368', 'Yuma', 'AZ', '85366-2361')
# ('6569995619', 'WIND RVR FAM & COMM HLTH CARE', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '14 Great Plains Rd', 'Arapahoe', 'WY', '82510-9144')
# ('6565743164', 'WIND RIVER CARES - ETHETE', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '510 Ethete Rd', 'Lander', 'WY', '82520')
# ('6565177533', 'WIND RIVER CARES - RIVERTON', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '511 N 12th St E', 'Riverton', 'WY', '82501-3809')
# ('6564978120', 'FORT WASHAKIE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '29 Black Coal Dr', 'Fort Washakie', 'WY', '82514')
# ('6559999409', 'NEKOOSA FIELD HEALTH OFFICE', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '916 Chak Ha Chee Ln', 'Nekoosa', 'WI', '54457-9602')
# ('65599955SA', 'IGNACE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '930 W Historic Mitchell St', 'Milwaukee', 'WI', '53204-3533')
# ('6.56E+12', 'LAC COURTE OREILLES HEALTH CTR', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '13380 W Trepania Rd', 'Hayward', 'WI', '54843-2186')
# ('65599955B3', 'ST CROIX HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4404 State Road 70', 'Webster', 'WI', '54893-9251')
# ('65599955B2', 'ONEIDA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '525 Airport Dr', 'Oneida', 'WI', '54155-9035')
# ('65599955B1', 'BAD RIVER HEALTH SERVICES', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '53585 Nokomis Rd', 'Ashland', 'WI', '54806-4272')
# ('65599955A9', 'P CHRISTENSEN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '129 Old Abe Rd', 'Lac Du Flambeau', 'WI', '54538-9386')
# ('65599955A5', 'MENOMINEE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'W3275 Wolf River Dr', 'Keshena', 'WI', '54135-9202')
# ('65599955A4', 'MOLE LAKE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3144 Vanzile Rd', 'Crandon', 'WI', '54520-8149')
# ('65599955A3', 'POTAWATOMI HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '8201 Mish Ko Swen Dr', 'Crandon', 'WI', '54520-8631')
# ('65599955A2', 'STOCKBRIDGE MUNSEE HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'County Road A', 'Bowler', 'WI', '54416')
# ('6559995599', 'RED CLIFF HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '36745 Aiken Rd', 'Bayfield', 'WI', '54814-4579')
# ('6557949757', 'AMERICAN INDIAN COUNCIL ON ALCOHOLISM', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '6510 W Layton Ave Ste 101', 'Greenfield', 'WI', '53220-4563')
# ('6557128165', 'TOMAH HLTH LOCATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1505 Butts Ave', 'Tomah', 'WI', '54660-2405')
# ('6553919193', 'HO-CHUNK WELLNESS CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'S2845 White Eagle Rd', 'Baraboo', 'WI', '53913-9064')
# ('6551768435', 'BLACK RIVER FALLS HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'N6520 Lumberjack Guy Rd', 'Black River Falls', 'WI', '54615-5405')
# ('65399953F9', 'Lummi Tribal Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2592 Kwina Rd', 'Bellingham', 'WA', '98226-9278')
# ('65399953F1', 'YAKAMA INDIAN HEALTH CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '401 Buster Rd', 'Toppenish', 'WA', '98948-9792')
# ('6.54E+16', 'DAVID C. WYNCOOP MEMORIAL CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '6205 Wellpinit Agency Loop Rd', 'Wellpinit', 'WA', '99040')
# ('6.54E+11', 'White Swan Dental Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '514 Signal Peak Rd', 'White Swan', 'WA', '98952')
# ('6.54E+08', 'Shoalwater Bay Wellness Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2373 Tokeland Rd', 'Tokeland', 'WA', '98590-9729')
# ('65399953C9', 'Roger Saux Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1505 Kla-ook-wa Dr', 'Taholah', 'WA', '98587')
# ('65399953C8', 'Takopid Indian Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2209 E 32nd St', 'Tacoma', 'WA', '98404-4922')
# ('65399953C7', 'Suquamish Tribes Wellness Program', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '18490 Suquamish Way NE Unit 107', 'Suquamish', 'WA', '98392-9533')
# ('65399953C5', 'Sally Selvidge Clinic (Health & Human Services Dept)', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '90 SE Klah Che Min Dr', 'Shelton', 'WA', '98584-9216')
# ('65399953C3', "Jamestown S'Klallam Family Health Center", 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '808 N 5th Ave', 'Sequim', 'WA', '98382-3045')
# ('65399953C2', 'Upper Skagit Tribal Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '25959 Community Plaza Way', 'Sedro Woolley', 'WA', '98284-9721')
# ('65399953C1', 'Lower Elwha Klallam Medical Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '243511 W Highway 101', 'Port Angeles', 'WA', '98363-9472')
# ('65399953B8', 'Nisqually Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4816 She Nah Num Dr SE', 'Olympia', 'WA', '98513-9105')
# ('65399953B7', 'Chehalis Community Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '21 Niederman Rd', 'Oakville', 'WA', '98568-8904')
# ('65399953B6', 'Sophie Trettevick Indian Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '250 Fort St', 'Neah Bay', 'WA', '98357-4003')
# ('65399953B3', 'Cowlitz Tribal Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1044 11th Ave', 'Longview', 'WA', '98632-2506')
# ('65399953B2', 'Quileute Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '560 Quileute Hts', 'La Push', 'WA', '98350')
# ('65399953B1', 'Swinomish Tribal Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '17400 Reservation Rd', 'La Conner', 'WA', '98257-8801')
# ('65399953A9', "Port Gamble S'Klallam Tribe Health Facility", 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '32014 Little Boston Rd NE', 'Kingston', 'WA', '98346-9734')
# ('65399953A7', 'Nooksack Community Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2510 Sulwhanon Dr', 'Everson', 'WA', '98247-8766')
# ('65399953A6', 'Sauk-Suiattle Tribal Community Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '5318 Chief Brown Ln', 'Darrington', 'WA', '98241-9420')
# ('65399953A5', 'Muckleshoot Tribal Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '17500 SE 392nd St', 'Auburn', 'WA', '98092-9705')
# ('6539995383', 'COLVILLE INDIAN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '19 Lakes St', 'Nespelem', 'WA', '99155')
# ('6539808975', 'Tulalip Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '7520 Totem Beach Rd', 'Tulalip', 'WA', '98271-6160')
# ('6539728581', 'Camas Path Behavioral Health', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1000 S Garfield Rd', 'Airway Heights', 'WA', '99001')
# ('6539685328', 'White Swan Tribal Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '80 Birdsong Lane', 'White Swan', 'WA', '98952')
# ('6539590617', 'Chehalis Family Services', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '420 Howanut Rd', 'Oakville', 'WA', '98568-9659')
# ('6539546512', 'Stilaguamish Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '902 E Maple St', 'Arlington', 'WA', '98223-1634')
# ('6539172608', 'Raging River Recovery Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1308 Boalch Ave NW', 'North Bend', 'WA', '98045-8908')
# ('6539156913', 'Omak Behavioral Health Program Chiliwist', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '507 S. Benton Street', 'Nespelem', 'WA', '99155')
# ('6538508989', 'Cowlitz Tribal Behavioral Health - Annex', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '922 Fir St', 'Longview', 'WA', '98632-2525')
# ('6537888164', 'North Bend Family Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '404 Main Ave S', 'North Bend', 'WA', '98045-8215')
# ('6537861659', 'Samish Indian Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2918 Commercial Ave', 'Anacortes', 'WA', '98221-2738')
# ('6536978494', 'Seattle Indian Health Board Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '611 12th Ave S Ste 200', 'Seattle', 'WA', '98144-2007')
# ('6536816767', 'Puyallup Tribal Integrative Medicine', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3700 Pacific Hwy E', 'Fife', 'WA', '98424-1148')
# ('6536515561', 'The People Place', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Community Hall Rd', 'Cusick', 'WA', '99119')
# ('6534475653', 'Omak Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '617 Benton St', 'Omak', 'WA', '98841-9636')
# ('6533592100', 'Skokomish Tribe', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '100 N Tribal Center Rd', 'Skokomish Nation', 'WA', '98584-9748')
# ('6533043505', 'Native Project', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1803 W Maxwell Ave', 'Spokane', 'WA', '99201-2831')
# ('6533024344', 'Sanpoil Valley Community Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '11665 S Highway 21', 'Keller', 'WA', '99140-9537')
# ('6532797122', 'Inchelium Community Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '39 Short Cut Rd', 'Inchelium', 'WA', '99138')
# ('6532724791', 'Camas Center for Community Wellness', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1821 Leclerc Rd N Ste 1', 'Cusick', 'WA', '99119-5015')
# ('6531724530', 'Muckleshoot Behavioral Health Program', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '17500 SE 392nd St', 'Auburn', 'WA', '98092-9705')
# ('6531007186', 'Inchelium Behavioral Health Program', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '320 Shortcut Road', 'Nespelem', 'WA', '99155')
# ('649999495M', 'SKULL VALLEY HEALTH CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1929 N Aaron Dr Ste I', 'Tooele', 'UT', '84074-8112')
# ('649999495H', 'SHIVWITS CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '6109 W 3700 N', 'Ivins', 'UT', '84738-6663')
# ('649999495D', 'URBAN INDIAN CENTER SALT LAKE', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '120 W 1300 S', 'Salt Lake City', 'UT', '84115-5230')
# ('6499994939', 'FT. DUCHESNE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2 Bottle Hollow Loop Rd', 'Fort Duchesne', 'UT', '84026')
# ('6498440326', 'NAVAJO MOUNTAIN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2 Rainbow City Rd', 'Monument Valley', 'UT', '84536')
# ('6497999528', 'KOOSHAREM CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '799 N Paiute Way', 'Richfield', 'UT', '84701-2070')
# ('6497252906', 'SACRED CIRCLE HEALTHCARE', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '660 S 200 E Ste 200', 'Salt Lake City', 'UT', '84111-3835')
# ('6496379304', 'MONUMENT VALLEY HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '30 W Medical Dr', 'Monument Valley', 'UT', '84536-7705')
# ('6494502685', 'BLANDING FAMILY HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '802 S 200 W', 'Blanding', 'UT', '84511-3910')
# ('6493086993', 'MONTEZUMA CREEK CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '100 UT-262', 'Montezuma Creek', 'UT', '84534')
# ('6492182304', 'SAN JUAN FAMILY DENTAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '217 S 100 W', 'Monticello', 'UT', '84535')
# ('6488148187', 'ALABAMA-COUSHATTA HEALTH CENT', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '129 Daycare Rd', 'Livingston', 'TX', '77351-0061')
# ('6485188079', 'URBAN INTER-TRIBAL CENTER OF TX', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1283 Record Crossing Rd', 'Dallas', 'TX', '75235-6001')
# ('6469994644', 'MCLAUGHLIN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '6th St E', 'Mc Laughlin', 'SD', '57642')
# ('6469994642', 'ROSEBUD HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '400 Soldier Creek Dr', 'Rosebud', 'SD', '57570-8502')
# ('6469994639', 'WAGNER HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '111 Washington Ave NW', 'Wagner', 'SD', '57380-4300')
# ('6469994638', 'LOWER BRULE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Gall St', 'Lower Brule', 'SD', '57548')
# ('6469994636', 'FT. THOMPSON HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1323 Bia Rd 4', 'Chamberlain', 'SD', '57325')
# ('6469994635', 'FLANDREAU SANTEE SIOUX TRB HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '701 W Broad Ave', 'Flandreau', 'SD', '57028-1529')
# ('6469994624', 'WW KEEBLE HEALTH CARE CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '100 Lake Traverse Dr', 'Sisseton', 'SD', '57262-7046')
# ('6469994622', 'RAPID CITY HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3200 Canyon Lake Dr', 'Rapid City', 'SD', '57702-8114')
# ('6469994621', 'WANBLEE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '210 1st St', 'Wanblee', 'SD', '57577')
# ('6469994620', 'KYLE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1000 Health Center Road', 'Kyle', 'SD', '57752')
# ('6469994618', 'EAGLE BUTTE', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '24276 166th St', 'Dupree', 'SD', '57623')
# ('6469994617', 'PINE RIDGE HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Highway 18', 'Pine Ridge', 'SD', '57770')
# ('6469096980', 'SOUTH DAKOTA URBAN INDIAN CLIN', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '711 N Lake Ave', 'Sioux Falls', 'SD', '57104-2203')
# ('6469023546', 'GPA Youth Regional Treatment Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'PO BOX 680', 'Mobridge', 'SD', '57601-0680')
# ('6468218932', 'PIERRE URBAN INDIAN CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1714 Abbey Rd', 'Pierre', 'SD', '57501-7805')
# ('6468119190', 'LACREEK DISTRICT CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '119 S 1st Ave', 'Martin', 'SD', '57551-5835')
# ('6467239701', 'WHITE HORSE HS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Whitehorse Road/County 4', 'Whitehorse', 'SD', '57661')
# ('6465646175', 'BULLHEAD HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '102 Tatanka Street', 'Bullhead', 'SD', '57621')
# ('6465269248', 'CHERRY CREEK HS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '538 Dupree', 'Cherry Creek', 'SD', '57622')
# ('6464923749', 'SWIFTBIRD HS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'La Plant Road', 'La Plant', 'SD', '57652')
# ('6463302537', 'MANDERSON HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Indian Service Road 33', 'Manderson', 'SD', '57756')
# ('6462464162', 'WAKPALA HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Wakpala Road', 'Wakpala', 'SD', '57658')
# ('6459994583', 'CATAWBA HEALTH SERVICES', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2893 Sturgis Rd', 'Rock Hill', 'SC', '29730-6607')
# ('6449994426', 'NARRAGANSETT IND HLTH CTR', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '51 Old Mill Rd', 'Charlestown', 'RI', '02813-3322')
# ('64199941A7', 'Coos Tribal Health Center - Dental', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1245 Fulton Ave', 'Coos Bay', 'OR', '97420-2895')
# ('64199941A5', 'CHEMAWA INDIAN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3750 Chemawa Rd NE', 'Salem', 'OR', '97305-1119')
# ('64199941A4', 'Siletz Community Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '200 Gwee Shut Rd', 'Siletz', 'OR', '97380-2036')
# ('64199941A3', 'NARA Indian Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1776 SW Madison St', 'Portland', 'OR', '97205-1715')
# ('64199941A2', 'WARM SPRINGS HEALTH AND WELLNESS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Kot-Num Rd', 'Warm Springs', 'OR', '97761')
# ('6419994197', 'Cow Creek Health & Wellness Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2371 NE Stephens St Ste 200', 'Roseburg', 'OR', '97470-1399')
# ('6419994196', 'Yellowhawk Tribal Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '73265 Confederated Way', 'Pendleton', 'OR', '97801-9099')
# ('6419994195', 'Klamath Tribal Health & Family Services', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3949 S 6th St', 'Klamath Falls', 'OR', '97603-4746')
# ('6419994194', 'Grand Ronde Health & Wellness Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '9605 Grand Ronde Rd', 'Grand Ronde', 'OR', '97347-9712')
# ('6419994192', 'Wadatika Indian Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '100 Pasigo St', 'Burns', 'OR', '97720-2442')
# ('6416988565', 'Cow Creek Health & Wellness - Annex', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '480 Wartahoo Ln', 'Canyonville', 'OR', '97417-9683')
# ('6413671540', 'NARA Dental', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '12750 SE Stark St Bldg E', 'Portland', 'OR', '97233-1539')
# ('6412976463', 'Warm Springs Community Counseling Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1115 Autumn Ave', 'Warm Springs', 'OR', '97761')
# ('6412857993', 'Alcohol & Drug Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '100 Pasigo St', 'Burns', 'OR', '97720-2442')
# ('640999409Q', 'CN COOWEESCOOWEE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '395200 W 2900 Rd', 'Ochelata', 'OK', '74051-2463')
# ('640999409J', 'CN A-MO HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '900 N Owen Walters Blvd', 'Salina', 'OK', '74365-5003')
# ('640999409G', 'CARNEGIE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '212 E 4th St', 'Carnegie', 'OK', '73015-9471')
# ('640999409E', 'PAWNEE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1201 Heritage Cir', 'Pawnee', 'OK', '74058-3744')
# ('640999409B', 'ANADARKO HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '115 NE Old Town Rd', 'Anadarko', 'OK', '73005-5009')
# ('640999409A', 'CN WILL ROGERS HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1020 Lenape Dr', 'Nowata', 'OK', '74048-4403')
# ('6409994099', 'CN VINITA HEALTH CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '27371 S 4410 Rd', 'Vinita', 'OK', '74301-7953')
# ('6409994098', 'Koweta Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '31870 E State Highway 51', 'Coweta', 'OK', '74429-7900')
# ('6409994096', 'INDIAN HLTH RESOURCE (TULSA)', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '550 S Peoria Ave', 'Tulsa', 'OK', '74120-3820')
# ('6409994084', 'BEARSKIN HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1 Turtle Dr', 'Wyandotte', 'OK', '74370-2114')
# ('6409994082', 'WEWOKA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'OK-56', 'Wewoka', 'OK', '74884')
# ('6409994081', 'WATONGA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1305 S Clarence Nash Blvd', 'Watonga', 'OK', '73772-4820')
# ('6409994078', 'EL RENO HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1801 Parkview Dr', 'El Reno', 'OK', '73036-2103')
# ('6409994071', 'Sapulpa Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1125 E Cleveland Ave', 'Sapulpa', 'OK', '74066-4641')
# ('6409994070', 'Cherokee Nation Redbird Smith Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '301 South JT Stiles Blvd', 'Sallisaw', 'OK', '74955')
# ('6409994065', 'WHITE EAGLE CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '200 White Eagle Dr', 'Ponca City', 'OK', '74601-8315')
# ('6409994064', 'PERKINS FAMILY CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '509 E Highway 33', 'Perkins', 'OK', '74059-4129')
# ('6409994059', 'Okemah Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '309 N 14th St', 'Okemah', 'OK', '74859-2028')
# ('6409994058', 'KANZA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3151 E River Rd', 'Newkirk', 'OK', '74647-7517')
# ('6409994057', 'OKMULGEE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1313 E 20th St', 'Okmulgee', 'OK', '74447-6303')
# ('6409994055', 'NORTHEASTERN TRIBAL HEALTH SYS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '7600 S Highway 69A', 'Miami', 'OK', '74354-1016')
# ('6409994047', 'CN Sam Hider Community Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '859 E Melton Dr', 'Jay', 'OK', '74346-2704')
# ('6409994018', 'CLINTON INDIAN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '10321 N 2274 Rd', 'Clinton', 'OK', '73601-7521')
# ('6409994017', 'CLAREMORE HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'S Moore Ave & W Will Rogers Blvd', 'Claremore', 'OK', '74017')
# ('6409994014', 'LAWTON HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1515 NE Lawrie Tatum Rd', 'Lawton', 'OK', '73507-3002')
# ('6409596437', 'Tishomingo Indian Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '815 E 6th St', 'Tishomingo', 'OK', '73460-1800')
# ('6408552802', 'JONES ACADEMY SCHOOL HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '909 Jones Academy Rd', 'Hartshorne', 'OK', '74547-5119')
# ('6408414311', 'CREEK NATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '309 N 14th St', 'Okemah', 'OK', '74859-2028')
# ('6408402118', 'Citizen Potawatomi Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2307 Gordon Cooper Dr', 'Shawnee', 'OK', '74801-9007')
# ('6408248951', 'RUBIN WHITE HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '109 Kerr Ave', 'Poteau', 'OK', '74953-5270')
# ('6408065256', 'Purcell Indian Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1438 Hardcastle Blvd', 'Purcell', 'OK', '73080-8233')
# ('6407624091', 'OKCIC Ann Arbor', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '309 S Ann Arbor Ave', 'Oklahoma City', 'OK', '73128-1112')
# ('6407466002', 'MCALESTER HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1127 S George Nigh Expy', 'Mcalester', 'OK', '74501-7143')
# ('6407406790', 'Cherokee Nation Ga Du Gi', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '16944 W Cherokee', 'Tahlequah', 'OK', '74464-5539')
# ('6406785885', 'CHICKASAW NATION MEDICAL CNTR', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1921 Stonecipher Dr', 'Ada', 'OK', '74820-3439')
# ('6405840516', 'CN Wilma P. Mankiller Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'RR 1 BOX East', 'Stilwell', 'OK', '74960-9801')
# ('6405835019', 'Choctaw Employee Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '698 Westside Dr Ste 108 # 110', 'Durant', 'OK', '74701-3085')
# ('6405795207', 'Stigler Choctaw Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2204 E Main St', 'Stigler', 'OK', '74462-2822')
# ('6405766025', 'ATOKA CHOCTAW NATION HLTH CTR', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1201 W Liberty Rd', 'Atoka', 'OK', '74525-1639')
# ('6405655419', 'Cherokee Nation Three Rivers Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1001 S 41st St E', 'Muskogee', 'OK', '74403-6253')
# ('6405646970', 'Kickapoo Health Center (McLoud)', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '407 N Highway 102', 'Mcloud', 'OK', '74851')
# ('6405536131', 'J ANDRSN HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '205 E 3rd St', 'Broken Bow', 'OK', '74728-4119')
# ('6405482605', 'HEALTHY LIVING CAMPUS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1400 Hensley Dr', 'Tahlequah', 'OK', '74464-5221')
# ('6405369450', 'MCN PHYSICAL REHAB CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '900 E Airport Rd', 'Okmulgee', 'OK', '74447-9082')
# ('6405213050', 'DURANT REGIONAL MEDICAL CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1801 Chukka Hina', 'Durant', 'OK', '74701-7117')
# ('6405156217', 'Eufaula HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '800 W Forrest Ave', 'Eufaula', 'OK', '74432-3249')
# ('6405054946', 'Ardmore Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2510 Chickasaw Blvd', 'Ardmore', 'OK', '73401-1341')
# ('6404818495', 'CPN West Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '781 Grand Casino Blvd', 'Shawnee', 'OK', '74804-1005')
# ('6404648671', 'CHOCTAW NATION HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1 Choctaw Way', 'Talihina', 'OK', '74571-2022')
# ('6404235740', 'Oklahoma City Indian Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4913 W Reno Ave', 'Oklahoma City', 'OK', '73127-6339')
# ('6403908310', 'Absentee Shawnee Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2029 Gordon Cooper Dr', 'Shawnee', 'OK', '74801-9005')
# ('6403395524', 'IDABEL HEALTH CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '902 E Lincoln Rd', 'Idabel', 'OK', '74745-7337')
# ('6403002685', 'HUGO HL CT', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '410 N M St', 'Hugo', 'OK', '74743-1820')
# ('6402323005', 'WAH-ZHA-ZHI HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '715 Grandview Ave', 'Pawhuska', 'OK', '74056-3201')
# ('6402188933', 'Choctaw Employee Health-Poteau', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '109 Kerr Ave', 'Poteau', 'OK', '74953-5270')
# ('6401853035', 'Black Hawk Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'PO BOX 247', 'Stroud', 'OK', '74079-0247')
# ('6401644759', 'CN WW HASTINGS INDIAN HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '100 S Bliss Ave', 'Tahlequah', 'OK', '74464-2512')
# ('6401284634', 'MCN MEDICAL CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1801 E 4th St', 'Okmulgee', 'OK', '74447-3942')
# ('6401060868', 'Little Axe Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '15951 Little Axe Dr', 'Norman', 'OK', '73026-9088')
# ('6389993811', 'FT. YATES HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'S River Rd', 'Fort Yates', 'ND', '58538')
# ('638999380A', 'TRENTON COMMUNITY CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '331 4th Ave E', 'Trenton', 'ND', '58853-9998')
# ('6389993808', 'QUENTIN N BURDICK MEM HLTH FACILITY', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '5 Moonlight Dr., Hwy.', 'Belcourt', 'ND', '58316')
# ('6388983196', 'MANDAREE HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '305 Main St', 'Mandaree', 'ND', '58757')
# ('6388218102', 'CANNONBAL HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Weasel St', 'Cannon Ball', 'ND', '58528')
# ('6387017160', 'WHITE SHIELD HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2 Central Main St Apt B', 'Roseglen', 'ND', '58775-6000')
# ('6385383086', 'PARSHALL HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '107 3rd St NE', 'Parshall', 'ND', '58770-7103')
# ('6384257024', 'SPIRIT LAKE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '74th Ave NE', 'Fort Totten', 'ND', '58335')
# ('6382066164', 'ELBOWOODS MEMORIAL HEALTH CTR', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1058 College Dr', 'New Town', 'ND', '58763-9112')
# ('6381794310', 'TWIN BUTTES HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '726 80th Ave NW', 'Halliday', 'ND', '58636-4001')
# ('63799937GK', 'CIHA OWENI CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '328 Airport Rd', 'Marble', 'NC', '28905-8878')
# ('6379568172', "CIHA WOMEN'S WELLNESS CTR", 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Kaiser Wilnoty Dr', 'Cherokee', 'NC', '28719')
# ('6375671004', 'CIHA MURPHY CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '59 Echota Church Rd', 'Cherokee', 'NC', '28719-9702')
# ('6374886573', 'CIHA DETEN CENT CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Seven Clans Ln', 'Whittier', 'NC', '28789')
# ('6374389525', 'UNITY HEALING CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '448 Sequoyah Trl', 'Cherokee', 'NC', '28719')
# ('6373696747', 'CIHA HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1 Hospital Rd', 'Cherokee', 'NC', '28719-9253')
# ('6373072682', 'CIHA A NA LE NI SGI', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '375 Sequoyah Trl', 'Cherokee', 'NC', '28719')
# ('6372719489', 'CIHA SNOWBIRD TREATMENT', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '96 Indian School Rd', 'Robbinsville', 'NC', '28771-7985')
# ('63699936GZ', 'CATTARAUGUS HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '36 Thomas Indian School Dr', 'Irving', 'NY', '14081-9300')
# ('63699936GY', 'LIONEL R JOHN ALLEGANY HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '987 R C Hoag Dr', 'Salamanca', 'NY', '14779-1365')
# ('63699936C1', 'ST REGIS MOHAWK HLTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '412 State Route 37', 'Hogansburg', 'NY', '13655-3109')
# ('6369318951', 'ONEIDA NATION FAMILY SERVICES', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2057 Dream Catcher Plz', 'Oneida', 'NY', '13421-2729')
# ('6367392033', 'LOCKPORT HEALTH SERVICES', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '6507 Wheeler Rd', 'Lockport', 'NY', '14094-9416')
# ('6363319930', 'NEW YORK INDIAN COUNCIL, INC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4322 22nd St Ste 306', 'Long Island City', 'NY', '11101-5004')
# ('635999355T', 'SANTA CLARA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '30 Guachpangue Rd', 'Espanola', 'NM', '87532-8902')
# ('635999355S', 'ISLETA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1 Sagebrush St SW', 'Albuquerque', 'NM', '87105-3942')
# ('635999355R', 'PUEBLO PINTADO HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '43 miles west of Cuba, NM on Navajo Hwy 9', 'Cuba', 'NM', '87013')
# ('635999355O', 'TAOS-PICURIS INDIAN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Goat Springs Rd', 'Taos', 'NM', '87571')
# ('635999355K', 'TOHATCHI HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '07 Choosgai Drive', 'Tohatchi', 'NM', '87325')
# ('635999355J', 'PINE HILL HC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'BIA Route 140', 'Pinehill', 'NM', '87357')
# ('635999355I', 'Alamo Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '60 NM-169', 'Magdalena', 'NM', '87825')
# ('635999355F', 'CANONCITO HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Medicine Horse Dr', 'Laguna', 'NM', '87026')
# ('635999355E', 'COCHITI HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '255 Cochiti St', 'Cochiti Pueblo', 'NM', '87072')
# ('635999355B', 'ZIA HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '155 Capitol Square Dr', 'Zia Pueblo', 'NM', '87053-6013')
# ('6359993559', 'JEMEZ HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '110 Sheep Springs Cir', 'Jemez Pueblo', 'NM', '87024')
# ('6359993555', 'JICARILLA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Stone Lake Rd', 'Dulce', 'NM', '87528')
# ('6359993551', 'DZILTH NA O DITH LE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '6 Road 7586', 'Bloomfield', 'NM', '87413-4934')
# ('6359993535', 'ALBUQUERQUE INDIAN HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '801 Vassar Dr NE', 'Albuquerque', 'NM', '87106-2725')
# ('6359993534', 'GALLUP INDIAN MEDICAL CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '516 E Nizhoni Blvd', 'Gallup', 'NM', '87301-5748')
# ('6359993533', 'CROWNPOINT HEALTHCARE FACILITY', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'NM-371 & W Route 9', 'Crownpoint', 'NM', '87313')
# ('6359993532', 'ZUNI INDIAN HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '21 B Ave', 'Zuni', 'NM', '87327')
# ('6359993531', 'NORTHERN NAVAJO MEDICAL CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'US-491 N', 'Shiprock', 'NM', '87420')
# ...
# ('6067525141', 'Crescent City Dental Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '785 E Washington Blvd Ste 8', 'Crescent City', 'CA', '95531-8372')
# ('6067477391', 'Fortuna Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3302 Renner Dr Ste C', 'Fortuna', 'CA', '95540-7103')
# ('6067017153', 'San Andreas Community Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '265 W Saint Charles St', 'San Andreas', 'CA', '95249-9618')
# ('6067003927', 'THEODORE ROOSEVELT SCHOOL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '5723 Whittier Blvd', 'Los Angeles', 'CA', '90022-4222')
# ('6066954583', 'Northern Valley Indian Health Chico Cohasset', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '500 Cohasset Rd Ste 15', 'Chico', 'CA', '95926-2260')
# ('6066813445', 'Yreka - Karuk Tribal Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1519 S Oregon St', 'Yreka', 'CA', '96097-3425')
# ('6066523000', 'Karuk Tribe of California Clinic - Orleans', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Asip Rd', 'Orleans', 'CA', '95556')
# ('6065385732', 'Toiyabe Dialysis Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '44 N Tu Su Ln', 'Bishop', 'CA', '93514-8058')
# ('6065298807', 'Feather River Tribal Health, Inc.', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2145 5th Ave', 'Oroville', 'CA', '95965-5870')
# ('6065261797', 'North Fork Indian Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '32938 Road 222 Ste 2', 'North Fork', 'CA', '93643-9562')
# ('6065209586', "K'ima:w Medical Center", 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Weitchpec Route, Libby Nix Community Center', 'Hoopa', 'CA', '95546')
# ('6065176567', 'Rolling Hills Clinic- Corning', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '740 Solano St', 'Corning', 'CA', '96021-3352')
# ('6065110504', 'Tachi Medical Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '16835 Alkali Dr Ste M', 'Lemoore', 'CA', '93245-9463')
# ('6065051099', 'Mariposa Indian Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '5192 Hospital Rd', 'Mariposa', 'CA', '95338-9524')
# ('6064895984', 'Elk Valley Health Station', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2298 Norris Ave', 'Crescent City', 'CA', '95531-9344')
# ('6064648870', 'Greenville Rancheria Indian Health', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '410 Main St', 'Greenville', 'CA', '95947-9514')
# ('6064148618', 'Indian Health Center of Santa Clara Valley', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1333 Meridian Ave', 'San Jose', 'CA', '95125-5212')
# ('6063776002', 'Central Valley Indian Health, Bullard Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '222 W Bullard Ave Ste 109', 'Clovis', 'CA', '93612-0801')
# ('6063168623', 'Bishop Toiyabe Healthcare Facility', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '250 N See Vee Ln', 'Bishop', 'CA', '93514-8130')
# ('6063082062', 'Modoc Indian Health Project DBA Strong Family Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1203 Oak St', 'Alturas', 'CA', '96101-3225')
# ('6062988800', 'Lone Pine Indian Health Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1150 Goodwin Rd', 'Lone Pine', 'CA', '93545-3005')
# ('6062700619', 'Yuba City Indian Health Station', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '555 W Onstott Rd', 'Yuba City', 'CA', '95993-5654')
# ('6062253177', 'Crescent City Medical Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1675 Northcrest Dr', 'Crescent City', 'CA', '95531-8928')
# ('6062136357', 'Friendship House - Assoc. of Amer. Indians, Inc.', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '56 Julian Ave', 'San Francisco', 'CA', '94103-3507')
# ('6062102111', 'Manchester-Point Arena Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '24 Mamie Laiwa Dr', 'Point Arena', 'CA', '95468')
# ('6062086906', 'Red Bluff Dental Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2500 Main St', 'Red Bluff', 'CA', '96080-2336')
# ('6061955799', 'Coleville Clinic', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '73 Camp Antelope Rd', 'Coleville', 'CA', '96107-9502')
# ('6061930512', 'Happy Camp', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '64236 2nd Ave', 'Happy Camp', 'CA', '96039')
# ('6061142779', 'Sonora Indian Health Center', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '13975 Mono Way Ste G', 'Sonora', 'CA', '95370-2824')
# ('60499904Z1', 'FOUR CORNERS REGIONAL HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'US-160 & Navajo Trl', 'Teec Nos Pos', 'AZ', '86514')
# ('60499904GD', 'SUPAI', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Main Street', 'Supai', 'AZ', '86435')
# ('60499904FZ', 'SACRED PEAKS HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '3480 E Route 66', 'Flagstaff', 'AZ', '86004-4032')
# ('60499904FY', 'HU-HU-KAM MEMORIAL HOSP', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '483 W Seed Farm Rd', 'Sacaton', 'AZ', '85147-5000')
# ('60499904FN', 'SAGE MEMORIAL HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'US-191 & AZ-264', 'Ganado', 'AZ', '86505')
# ('60499904FA', 'INSCRIPTION HOUSE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'AZ-98', 'Shonto', 'AZ', '86054')
# ('60499904EX', 'AK CHIN', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '48203 W Farrell Rd', 'Maricopa', 'AZ', '85139-3806')
# ('60499904EV', 'KAIBAB-PAIUTE HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Pipe Springs Rd', 'Fredonia', 'AZ', '86022')
# ('6.05E+10', 'NACA FAMILY HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2717 N Steves Blvd Ste 11', 'Flagstaff', 'AZ', '86004-3959')
# ('60499904D6', 'SAN CARLOS APACHE HEALTH CORP', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '103 Medicine Way Rd', 'Peridot', 'AZ', '85542')
# ('60499904D5', 'WASSAJA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '16240 N Fort Mcdowell Rd', 'Fort Mcdowell', 'AZ', '85264-3402')
# ('60499904C3', 'YAVAPAI APACHE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2121 W Reservation Loop Rd', 'Camp Verde', 'AZ', '86322')
# ('60499904B9', 'CIBECUE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'North Cromwell Road', 'Cibecue', 'AZ', '85911')
# ('60499904B8', 'BYLAS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '101 Medical Dr', 'Bylas', 'AZ', '85530')
# ('60499904B7', 'SALT RIVER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '10005 E Osborn Rd Bldg 13', 'Scottsdale', 'AZ', '85256-4019')
# ('60499904B6', 'PEACH SPRINGS', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '943 Hualapai Way', 'Peach Springs', 'AZ', '86434')
# ('6049990497', 'TSAILE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Route 64 @ Indian Road 12; P.O. Box 467', 'Tsaile', 'AZ', '86556')
# ('6049990494', 'PHOENIX INDIAN MEDICAL CENTER (PIMC)', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4212 N 16th St', 'Phoenix', 'AZ', '85016-5319')
# ('6049990493', 'KAYENTA HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'US-160', 'Kayenta', 'AZ', '86033')
# ('6049990491', 'PARKER HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '12033 Agency Rd', 'Parker', 'AZ', '85344-7718')
# ('6049990490', 'HOPI HEALTH CARE CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'AZ-264', 'Polacca', 'AZ', '86042')
# ('6049990489', 'WHITERIVER H', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'W Hospital Dr', 'Show Low', 'AZ', '85901')
# ('6049990487', 'FORT DEFIANCE INDIAN HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Corner of N-12 and N-7', 'Fort Defiance', 'AZ', '86504')
# ('6049990486', 'CHINLE HOSPITAL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'Highway 191', 'Chinle', 'AZ', '86503')
# ('6049990485', 'WINSLOW INDIAN HEALTH CARE CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '500 Indiana Ave', 'Winslow', 'AZ', '86047-2169')
# ('604999040E', 'ROCK POINT HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'c/o Chinle Comprehensive Health Care Fac.', 'Rock Point', 'AZ', '86545')
# ('604999040D', 'MANY FARMS DENTAL CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'US-191 & Lake Rd', 'Many Farms', 'AZ', '86538')
# ('604999040B', 'PINON HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'NR 4, 2 Miles East of Pinon', 'Pinon', 'AZ', '86510')
# ('6049527004', 'DILKON CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'AZ Hwy. 87 at IR 15, 39 miles north of Winslow, AZ', 'Winslow', 'AZ', '86047')
# ('6049282849', 'CANYON DAY JUNIOR HIGH SCHOOL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4621 South 9th Street', 'Whiteriver', 'AZ', '85941')
# ('6049054535', 'CIBECUE HEADSTART', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '24 North Cromwell Road', 'Cibecue', 'AZ', '85911')
# ('6048810213', 'TUBA CITY REGIONAL HEALTH CARE CORPORATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'N Main St & E Elm Ave', 'Tuba City', 'AZ', '86045')
# ('6047747817', 'FORT MOJAVE', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1607 E Plantation Rd', 'Mohave Valley', 'AZ', '86440-8420')
# ('6047436201', 'MARY V. RILEY SEVEN MILE SCH', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '2005 Fort Apache Rd.', 'Pinetop', 'AZ', '85935')
# ('6046717352', 'SACRED PEAKS HEALTH CENTER WEST', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1338 W Forest Meadows St Ste 140', 'Flagstaff', 'AZ', '86001-7226')
# ('6045977062', 'MCNARY HEADSTART', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '110 W Pine St', 'Show Low', 'AZ', '85901')
# ('6045766311', 'FORT MOJAVE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '5330 S Highway 95', 'Fort Mohave', 'AZ', '86426-9225')
# ('6045614158', 'DENNEHOTSO HEALTH STATION', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'US-160', 'Teec Nos Pos', 'AZ', '86514')
# ('6045448475', 'KOMATKE HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '17487 S Healthcare Dr', 'Laveen', 'AZ', '85339-8500')
# ('6045264087', 'LEUPP CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1.5 miles north of Leupp Chapter House', 'Joseph City', 'AZ', '86032')
# ('6045189917', 'NATIVE HEALTH', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4041 N Central Ave Bldg C', 'Phoenix', 'AZ', '85012-3313')
# ('6044866426', 'GREASEWOOD CLINIC', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', None, 'Greasewood', 'AZ', '86505')
# ('6044861124', 'DESERT VISIONS RTC-SACATON', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'N Skill Center Rd', 'Sacaton', 'AZ', '85147')
# ('6044450612', 'WHITE MTN APACHE HEADSTART', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '311 N 1st Ave', 'Whiteriver', 'AZ', '85941')
# ('6044040864', 'WHITERIVER ELEMENTARY SCHOOL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', 'N 1st Ave', 'Whiteriver', 'AZ', '85941')
# ('6043918770', 'NA CARDIOLOGY PROG FLAGSTAFF', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '1215 N Beaver St Ste 201', 'Flagstaff', 'AZ', '86001-3126')
# ('6043906683', 'EAST FORK LUTHERAN SCHOOL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '4325 Fort Apache Rd.', 'Whiteriver', 'AZ', '85941')
# ('6042473681', 'NAHATA DZIIL HEALTH CENTER', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', "Chiih'tow Boulevard", 'Sanders', 'AZ', '86512')
# ('6042421598', 'JOHN F. KENNEDY SCHOOL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '110 W. Dish Chin Rd.', 'Whiteriver', 'AZ', '85941')
# ('6042144212', 'CRADLEBOARD ELEMENTARY SCHOOL', 'D', 'Designated', 'ITU', 'Indian Health Service, Tribal Health, and Urban Indian Health Organizations', '7301 Power Line Rd', 'Whiteriver', 'AZ', '85941')
# Connection closed

# %%
# print all columns for all tables 
sheet1_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'Address', 'City', 'State_Abbr',
#        'Postal_Code', 'Designation_Date', 'Designation_Last_Update_Date',
#        'Designation_Pop', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc', 'Component_Source_ID',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Geography_ID', 'CountyFIPS', 'County_Name', 'StateCountyFIPS',
#        'State_FIPS', 'State_Abbr_2', 'State_Name', 'Primary_State_Name',
#        'Primary_State_FIPS', 'Primary_HHS_Region_Name',
#        'US_Mexico_Border_County', 'US_Mexico_Border_100km',
#        'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'Geocoding_Primary_X',
#        'Geocoding_Primary_Y', 'Common_City_Name_with_State_Abbr',
#        'Common_Postal_Code', 'Common_County_Name', 'Common_StateCounty_FIPS',
#        'Common_State_Abbr', 'Common_State_Name', 'Common_State_FIPS',
#        'Common_Region_Name', 'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet2_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'State_Abbr', 'Degree_of_Shortage',
#        'Designation_Date', 'Designation_Last_Update_Date', 'Designation_Pop',
#        'Estimated_Underserved_Pop', 'Estimated_Served_Pop', 'Formal_Ratio',
#        'Total_FTE_Clinicians', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'Provider_Ratio_Goal',
#        'Percent_Pop_Below_Poverty', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Component_State_Abbr', 'Component_Designation_Date',
#        'Component_Designation_Date_String',
#        'Component_Designation_Last_Update_Date', 'Geography_ID', 'CountyFIPS',
#        'County_Name', 'StateCountyFIPS', 'State_FIPS', 'State_Abbr_2',
#        'State_Name', 'Primary_State_Name', 'Primary_State_FIPS',
#        'Primary_HHS_Region_Name', 'US_Mexico_Border_County',
#        'US_Mexico_Border_100km', 'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'HPSA_Pop_Type_Code',
#        'HPSA_Pop_Type_Desc', 'HPSA_Resident_Civilian_Pop',
#        'Common_County_Name', 'Common_StateCounty_FIPS', 'Common_State_Abbr',
#        'Common_State_Name', 'Common_State_FIPS', 'Common_Region_Name',
#        'HPSA_Withdrawn_Date', 'HPSA_Withdrawn_Date_String', 'Provider_Type',
#        'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet3_data.columns
# Out:
# Index(['Source_ID', 'Source_Name', 'Status_Code', 'Status_Description',
#        'Type_Code', 'Type_Desc', 'Address', 'City', 'State_Abbr',
#        'Postal_Code', 'Designation_Date', 'Designation_Last_Update_Date',
#        'Designation_Pop', 'Metropolitan_Indicator_Code',
#        'Metropolitan_Indicator_Desc', 'HPSA_Score', 'HPSA_Shortage',
#        'Discipline_Class_Num', 'Discipline_Class_Desc', 'Component_Source_ID',
#        'Component_Source_Name', 'Component_Status_Code',
#        'Component_Status_Desc', 'Component_Type_Code', 'Component_Type_Desc',
#        'Geography_ID', 'CountyFIPS', 'County_Name', 'StateCountyFIPS',
#        'State_FIPS', 'State_Abbr_2', 'State_Name', 'Primary_State_Name',
#        'Primary_State_FIPS', 'Primary_HHS_Region_Name',
#        'US_Mexico_Border_County', 'US_Mexico_Border_100km',
#        'Data_Warehouse_Record_Create_Date',
#        'Data_Warehouse_Record_Create_Date_Text', 'HPSA_Name',
#        'HPSA_Component_Name', 'Break_in_Designation', 'Geocoding_Primary_X',
#        'Geocoding_Primary_Y', 'Common_City_Name_with_State_Abbr',
#        'Common_Postal_Code', 'Common_County_Name', 'Common_StateCounty_FIPS',
#        'Common_State_Abbr', 'Common_State_Name', 'Common_State_FIPS',
#        'Common_Region_Name', 'Rural_Status_Code', 'Rural_Status_Desc',
#        'HPSA_Designation_Pop_Type_Desc'],
#       dtype='object')

# %%
sheet4_data.columns
# Out:
# Index(['MUA_SOURCE_ID', 'MUA_AREA_CD', 'MUA_DESIGNATION_TYP_CD',
#        'MUA_DESIGNATION_TYP_DESC', 'MUA_STATUS_CD', 'MUA_STATUS_DESC',
#        'CENSUS_TRACT', 'MUA_DESIGNATION_DT', 'MUA_DESIGNATION_DT_TXT',
#        'MUA_SCORE', 'MUA_SERVICE_AREA_NM', 'MUA_UPDATE_DT',
#        'MUA_UPDATE_DT_TXT', 'US_MEXICO_BORDER_100KM_IND',
#        'US_MEXICO_BORDER_COUNTY_IND', 'STATE_COUNTY_FIPS_CD', 'COUNTY_FIPS_CD',
#        'LIST_BOX_COUNTY_NM', 'COUNTY_NM', 'COUNTY_DESC', 'REGION_CD',
#        'REGION_NM', 'STATE_FIPS_CD', 'STATE_NM', 'STATE_ABBR',
#        'POVERTY_100_PCT_NUM', 'POP_AGE_65_OVER_PCT', 'INFANT_MORTALITY_RATE',
#        'DW_RECORD_CREATE_DT', 'DW_RECORD_CREATE_DT_TXT',
#        'PRIMARY_STATE_FIPS_CD', 'PRIMARY_STATE_ABBR', 'PRIMARY_STATE_NM',
#        'PRIMARY_REGION_CD', 'PRIMARY_REGION_NM', 'CMN_REGION_CD',
#        'CMN_REGION_NM', 'CMN_STATE_NM', 'CMN_STATE_ABBR', 'CMN_STATE_FIPS_CD',
#        'CMN_STATE_COUNTY_FIPS_CD', 'CMN_COUNTY_NM_STATE_ABBR',
#        'BREAK_DESIGNATION_IND', 'MUA_COMP_DESIGNATION_DT',
#        'MUA_COMP_DESIGNATION_DT_TXT', 'MUA_COMP_GEO_NM', 'MUA_COMP_GEO_TYP_CD',
#        'MUA_COMP_GEO_TYP_DESC', 'MUA_COMP_GEO_TYP_ID',
#        'MUA_COMP_LAST_UPDATE_DT', 'MUA_COMP_STATUS_CD', 'MUA_COMP_STATUS_DESC',
#        'MUA_COMP_UPDATE_DT_TXT', 'MUA_DESIGNATION_POP', 'MUA_METRO_IND_CD',
#        'MUA_METRO_IND_DESC', 'MUA_METRO_IND_ID', 'MUA_POPULATION_TYP_CD',
#        'MUA_POPULATION_TYP_DESC', 'MUA_POPULATION_TYP_ID', 'MUA_RES_CIV_POP',
#        'RURAL_STATUS_CD', 'RURAL_STATUS_DESC', 'PROVIDER_1000_POP'],
#       dtype='object')

# %% [markdown]
# ### Usage - Queries Procedures

# %%
# Function to fetch and print tables with headers
def print_tables():
    try:
        conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
        if conn.is_connected():
            cursor = conn.cursor(dictionary=True)

            # Fetch table names
            cursor.execute("SHOW TABLES")
            tables = cursor.fetchall()

            # Print tables with headers
            for table in tables:
                table_name = table['Tables_in_task_x']
                print(f"Table: {table_name}")

                # Fetch and print table data with headers
                cursor.execute(f"SELECT * FROM {table_name}")
                result = cursor.fetchall()

                if result:
                    df = pd.DataFrame(result)
                    print(df)

                print("\n")

    except Error as e:
        print(f"Error: {e}")

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

# Print tables with headers
print_tables()
# Out:
# Table: hpsa_dental_health
#       Source_ID                              Source_Name Status_Code  \
# 0    6409994016              Carl Albert Indian Hospital           W
# 1    6319993124            Winnebago PHS Indian Hospital           W
# 2    6089990849  Southern Colorado Ute Services Unit-Fed           W
# 3    60499904B5   Phx Area Office Two Renaissance Square           W
# 4    6569995629    Ft. Washakie PHS Indian Health Center           D
# ..          ...                                      ...         ...
# 495  6043918770             NA CARDIOLOGY PROG FLAGSTAFF           D
# 496  6043906683                EAST FORK LUTHERAN SCHOOL           D
# 497  6042473681               NAHATA DZIIL HEALTH CENTER           D
# 498  6042421598                   JOHN F. KENNEDY SCHOOL           D
# 499  6042144212            CRADLEBOARD ELEMENTARY SCHOOL           D
#
#     Status_Description Type_Code  \
# 0            Withdrawn       IHS
# 1            Withdrawn       IHS
# 2            Withdrawn       IHS
# 3            Withdrawn       IHS
# 4           Designated       IHS
# ..                 ...       ...
# 495         Designated       ITU
# 496         Designated       ITU
# 497         Designated       ITU
# 498         Designated       ITU
# 499         Designated       ITU
#
#                                              Type_Desc  \
# 0        Indian, Tribal and Urban Indian Organizations
# 1        Indian, Tribal and Urban Indian Organizations
# 2        Indian, Tribal and Urban Indian Organizations
# 3        Indian, Tribal and Urban Indian Organizations
# 4        Indian, Tribal and Urban Indian Organizations
# ..                                                 ...
# 495  Indian Health Service, Tribal Health, and Urba...
# 496  Indian Health Service, Tribal Health, and Urba...
# 497  Indian Health Service, Tribal Health, and Urba...
# 498  Indian Health Service, Tribal Health, and Urba...
# 499  Indian Health Service, Tribal Health, and Urba...
#
#                       Address           City State_Abbr Postal_Code
# 0      1001 N Country Club Rd            Ada         OK  74820-2847
# 1                   PO BOX Hh      Winnebago         NE  68071-0767
# 2               Weeminuche Dr        Ignacio         CO       81137
# 3                100 N 1st St        Phoenix         AZ       85004
# 4                  PO BOX 128  Fort Washakie         WY  82514-0128
# ..                        ...            ...        ...         ...
# 495  1215 N Beaver St Ste 201      Flagstaff         AZ  86001-3126
# 496      4325 Fort Apache Rd.     Whiteriver         AZ       85941
# 497       Chiih'tow Boulevard        Sanders         AZ       86512
# 498      110 W. Dish Chin Rd.     Whiteriver         AZ       85941
# 499        7301 Power Line Rd     Whiteriver         AZ       85941
#
# [500 rows x 10 columns]
#
#
# Table: hpsa_mental_health
#       Source_ID                           Source_Name Status_Code  \
# 0        733007                                  Coos           W
# 1    7449994412  Northern Rhode Island Catchment Area           W
# 2    7449994412  Northern Rhode Island Catchment Area           W
# 3    7449994412  Northern Rhode Island Catchment Area           W
# 4    7449994412  Northern Rhode Island Catchment Area           W
# ..          ...                                   ...         ...
# 495  7469994624                      Catchment Area 7           W
# 496  7469994624                      Catchment Area 7           W
# 497  7469994624                      Catchment Area 7           W
# 498  7469994624                      Catchment Area 7           W
# 499  7469994624                      Catchment Area 7           W
#
#     Status_Description Type_Code        Type_Desc State_Abbr  \
# 0            Withdrawn  Hpsa Geo  Geographic HPSA         NH
# 1            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# 2            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# 3            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# 4            Withdrawn  Hpsa Geo  Geographic HPSA         RI
# ..                 ...       ...              ...        ...
# 495          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 496          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 497          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 498          Withdrawn  Hpsa Geo  Geographic HPSA         SD
# 499          Withdrawn  Hpsa Geo  Geographic HPSA         SD
#
#     Degree_of_Shortage Designation_Date Designation_Last_Update_Date
# 0       Not applicable            29005                        37799
# 1       Not applicable            37672                        39671
# 2       Not applicable            37672                        39671
# 3       Not applicable            37672                        39671
# 4       Not applicable            37672                        39671
# ..                 ...              ...                          ...
# 495     Not applicable            36633                        43283
# 496     Not applicable            36633                        43283
# 497     Not applicable            36633                        43283
# 498     Not applicable            36633                        43283
# 499     Not applicable            36633                        43283
#
# [500 rows x 10 columns]
#
#
# Table: hpsa_mua
#     MUA_SOURCE_ID  MUA_AREA_CD MUA_DESIGNATION_TYP_CD  \
# 0             474   9013530200                    MUP
# 1             474   9013530100                    MUP
# 2             470   9005310300                    MUP
# 3             470   9005310500                    MUP
# 4             470   9005310801                    MUP
# ..            ...          ...                    ...
# 495          6165  34023004200                 MUP-GE
# 496          6165  34023004300                 MUP-GE
# 497          6165  34023004600                 MUP-GE
# 498          6165  34023005000                 MUP-GE
# 499          7539  34041030900                    MUA
#
#                               MUA_DESIGNATION_TYP_DESC MUA_STATUS_CD  \
# 0                     Medically Underserved Population             D
# 1                     Medically Underserved Population             D
# 2                     Medically Underserved Population             D
# 3                     Medically Underserved Population             D
# 4                     Medically Underserved Population             D
# ..                                                 ...           ...
# 495  Medically Underserved Population ?�ô Governor?...             D
# 496  Medically Underserved Population ?�ô Governor?...             D
# 497  Medically Underserved Population ?�ô Governor?...             D
# 498  Medically Underserved Population ?�ô Governor?...             D
# 499                         Medically Underserved Area             D
#
#     MUA_STATUS_DESC CENSUS_TRACT MUA_DESIGNATION_DT MUA_DESIGNATION_DT_TXT  \
# 0        Designated       5302.0              34676              12/8/1994
# 1        Designated       5301.0              34676              12/8/1994
# 2        Designated       3103.0              34676              12/8/1994
# 3        Designated       3105.0              34676              12/8/1994
# 4        Designated      3108.01              34676              12/8/1994
# ..              ...          ...                ...                    ...
# 495      Designated         42.0              36852             11/22/2000
# 496      Designated         43.0              36852             11/22/2000
# 497      Designated         46.0              36852             11/22/2000
# 498      Designated         50.0              36852             11/22/2000
# 499      Designated        309.0              34497              6/12/1994
#
#     MUA_SCORE
# 0        47.8
# 1        47.8
# 2        41.1
# 3        41.1
# 4        41.1
# ..        ...
# 495       0.0
# 496       0.0
# 497       0.0
# 498       0.0
# 499      62.0
#
# [500 rows x 10 columns]
#
#
# Table: hpsa_primary_care
#       Source_ID                                  Source_Name Status_Code  \
# 0    1569995651        Ft. Washakie PHS Indian Health Center           D
# 1    1469994698  McLaughlin PHS Indian Medical/Dental Clinic           D
# 2    1469994687                   Wagner PHS Indian Hospital           D
# 3    141999413V                         Portland Area Office           D
# 4    14099940N2                        Shawnee Health Center           D
# ..          ...                                          ...         ...
# 495  10299902AE                     Saint Paul Health Center           D
# 496  10299902AD                        Karluk Village Clinic           D
# 497  10299902AC                        Little Diomede Clinic           D
# 498  10299902AB                       Eklutna Village Clinic           D
# 499  1029990297                        Tyonek Village Clinic           D
#
#     Status_Description Type_Code  \
# 0           Designated       IHS
# 1           Designated       IHS
# 2           Designated       IHS
# 3           Designated       IHS
# 4           Designated       IHS
# ..                 ...       ...
# 495         Designated       ITU
# 496         Designated       ITU
# 497         Designated       ITU
# 498         Designated       ITU
# 499         Designated       ITU
#
#                                              Type_Desc  \
# 0        Indian, Tribal and Urban Indian Organizations
# 1        Indian, Tribal and Urban Indian Organizations
# 2        Indian, Tribal and Urban Indian Organizations
# 3        Indian, Tribal and Urban Indian Organizations
# 4        Indian, Tribal and Urban Indian Organizations
# ..                                                 ...
# 495  Indian Health Service, Tribal Health, and Urba...
# 496  Indian Health Service, Tribal Health, and Urba...
# 497  Indian Health Service, Tribal Health, and Urba...
# 498  Indian Health Service, Tribal Health, and Urba...
# 499  Indian Health Service, Tribal Health, and Urba...
#
#                       Address               City State_Abbr Postal_Code
# 0                  PO BOX 128      Fort Washakie         WY  82514-0128
# 1               611 2nd Ave E        Mc Laughlin         SD       57642
# 2       110 Washington Ave NW             Wagner         SD       57380
# 3     1220 SW 3rd Ave Ste 476           Portland         OR  97204-2825
# 4       2307 Gordon Cooper Dr            Shawnee         OK  74801-9007
# ..                        ...                ...        ...         ...
# 495       1000 Polivenia Tpke  Saint Paul Island         AK       99660
# 496          26 Alex Brown St             Karluk         AK       99608
# 497                      None               Nome         AK       99762
# 498  26339 Eklutna Village Rd            Chugiak         AK  99567-5148
# 499                   73 C St             Tyonek         AK       99682
#
# [500 rows x 10 columns]

# %%
import mysql.connector
from mysql.connector import Error

# Database connection details
host = 'localhost'
user = 'fr34k'
password = '1391'
database = 'task_x'

# Function to create stored procedures
def create_stored_procedures():
    try:
        conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
        if conn.is_connected():
            cursor = conn.cursor()

            # Stored Procedure 1: Get data from hpsa_primary_care
            sp1_query = """
                CREATE PROCEDURE GetPrimaryCareData()
                BEGIN
                    SELECT * FROM hpsa_primary_care;
                END
            """
            cursor.execute(sp1_query)
            print("Stored Procedure 1 created successfully.")

            # Stored Procedure 2: Get data from hpsa_dental_health
            sp2_query = """
                CREATE PROCEDURE GetDentalHealthData()
                BEGIN
                    SELECT * FROM hpsa_dental_health;
                END
            """
            cursor.execute(sp2_query)
            print("Stored Procedure 2 created successfully.")

            # Commit the changes
            conn.commit()

    except Error as e:
        print(f"Error: {e}")

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

# Create stored procedures
create_stored_procedures()
# Out:
# Error: 1698 (28000): Access denied for user 'root'@'localhost'
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-40-40a3bdfa5bb0> in <module>
#      47
#      48 # Create stored procedures
# ---> 49 create_stored_procedures()
#
# <ipython-input-40-40a3bdfa5bb0> in create_stored_procedures()
#      42
#      43     finally:
# ---> 44         if conn.is_connected():
#      45             cursor.close()
#      46             conn.close()
#
# UnboundLocalError: local variable 'conn' referenced before assignment

# %% [markdown]
# ![image3](image3.png)

# %%
import pandas as pd

# Function to execute queries and print results
def execute_queries():
    try:
        conn = mysql.connector.connect(host=host, user=user, password=password, database=database)
        if conn.is_connected():
            cursor = conn.cursor(dictionary=True)

            # Query 1: Get unique cities from hpsa_primary_care
            query1 = "SELECT DISTINCT City FROM hpsa_primary_care;"
            result1 = pd.read_sql(query1, conn)
            print("Query 1:")
            print(result1)

            # Query 2: Get the count of each Type_Desc from hpsa_dental_health
            query2 = "SELECT Type_Desc, COUNT(*) as Count FROM hpsa_dental_health GROUP BY Type_Desc;"
            result2 = pd.read_sql(query2, conn)
            print("\nQuery 2:")
            print(result2)
            
            # Query 3: Get the average MUA_SCORE for each MUA_STATUS_DESC in hpsa_mua
            query3 = "SELECT MUA_STATUS_DESC, AVG(MUA_SCORE) as Average_Score FROM hpsa_mua GROUP BY MUA_STATUS_DESC;"
            result3 = pd.read_sql(query3, conn)
            print("\nQuery 3:")
            print(result3)

                        
            query4 = """
                SELECT Source_Name, Address
                FROM hpsa_primary_care
                ORDER BY Address DESC
                LIMIT 5;
            """
            result4 = pd.read_sql(query4, conn)
            print("\nQuery 4:")
            print(result4)


    except Error as e:
        print(f"Error: {e}")

    finally:
        if conn.is_connected():
            cursor.close()
            conn.close()

# Execute queries
execute_queries()
# Out:
# Query 1:
#                   City
# 0        Fort Washakie
# 1          Mc Laughlin
# 2               Wagner
# 3             Portland
# 4              Shawnee
# ..                 ...
# 408  Saint Paul Island
# 409             Karluk
# 410               Nome
# 411            Chugiak
# 412             Tyonek
#
# [413 rows x 1 columns]
#
# Query 2:
#                                            Type_Desc  Count
# 0  Indian Health Service, Tribal Health, and Urba...    474
# 1      Indian, Tribal and Urban Indian Organizations     26
#
# Query 3:
#   MUA_STATUS_DESC  Average_Score
# 0      Designated       47.70276
#
# Query 4:
#                 Source_Name                                      Address
# 0     COCHITI DENTAL CLINIC                                  Windmill Rd
# 1            WHITE HORSE HS                     Whitehorse Road/County 4
# 2    K'ima:w Medical Center  Weitchpec Route, Libby Nix Community Center
# 3  CANNONBAL HEALTH STATION                                    Weasel St
# 4    WAKPALA HEALTH STATION                                 Wakpala Road
# <ipython-input-141-1c5ac15f1627>:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result1 = pd.read_sql(query1, conn)
# <ipython-input-141-1c5ac15f1627>:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result2 = pd.read_sql(query2, conn)
# <ipython-input-141-1c5ac15f1627>:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result3 = pd.read_sql(query3, conn)
# <ipython-input-141-1c5ac15f1627>:36: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result4 = pd.read_sql(query4, conn)

# %% [markdown]
# ### Conclusion:
# The project successfully leverages Python and MySQL to initialize and populate a database with four tables (hpsa_primary_care, hpsa_mental_health, hpsa_dental_health, and hpsa_mua). The script utilizes the pandas library to handle datasets, dynamically generates SQL queries for table creation and data insertion, and ensures proper error handling and connection closure.
#
# The database is structured to store information related to healthcare provider shortage areas, mental health designations, dental health designations, and medically underserved areas. This organized data lays the foundation for efficient querying and analysis.
#
# Additionally, the script includes functionality to perform user-defined SELECT queries, allowing users to retrieve specific information from the populated tables interactively.
#
# Overall, the project combines data management, database creation, and user interaction, providing a robust foundation for further development and analysis in the realm of healthcare data.
